# %%
# Standard libs
import os
import uuid
import random
import warnings
from typing import List, Dict
import json
import xattr

# Faker for PERSON/ORG/GPE fillers
from faker import Faker
fake = Faker()

# LlamaCpp & LangChain
from llama_cpp import Llama
from langchain_community.llms import LlamaCpp
from langchain.chains import LLMChain
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain_core.callbacks import CallbackManager, StreamingStdOutCallbackHandler

# Embeddings & Vector Store
from sentence_transformers import SentenceTransformer
import chromadb
from langchain_community.vectorstores import Chroma

# Silence LangChain deprecation warnings
from langchain._api import LangChainDeprecationWarning
warnings.simplefilter("ignore", category=LangChainDeprecationWarning)

# %%
# Cell 2 — Templates & Value Pools
# ─────────────────────────────────
templates: List[
    tuple[str, Dict[str,str]]
] = [
    (
        "The {vuln} vulnerability in {product} was exploited by {apt}.",
        {"vuln":"VULNERABILITY","product":"PRODUCT","apt":"APT_GROUP"},
    ),
    (
        "A {attack} targeted {org} using the {malware} backdoor.",
        {"attack":"ATTACK_TYPE","org":"ORG","malware":"MALWARE"},
    ),
    (
        "{person} from {org} discovered a zero-day {vuln}.",
        {"person":"PERSON","org":"ORG","vuln":"VULNERABILITY"},
    ),
    (
        "A new strain of {malware} was seen in {geo}.",
        {"malware":"MALWARE","geo":"GPE"},
    ),
    (
        "{org} alerted its users of a potential {attack} yesterday.",
        {"org":"ORG","attack":"ATTACK_TYPE"},
    ),
]

values: Dict[str,List[str]] = {
    "vuln":[f"CVE-{random.randint(2000,2023)}-{random.randint(1000,9999)}" for _ in range(200)],
    "product":["OpenSSL","Linux kernel","Windows 10","WordPress","Apache HTTPD"],
    "apt":["APT28","Lazarus Group","APT29","Sandworm Team","FIN7"],
    "attack":["phishing attack","DDoS","ransomware campaign","SQL injection"],
    "malware":["Emotet","TrickBot","Zeus","Ryuk","LockBit"],
    "person":[fake.name() for _ in range(200)],
    "org":[fake.company() for _ in range(100)],
    "geo":[fake.country() for _ in range(50)],
}

# %%
# 4) Spin up the LlamaCpp LLM via LangChain
model_path = "model/llama-2-7b-chat.Q4_K_M.gguf"  # ← your gguf on-disk
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])

llm = LlamaCpp(
    model_path=model_path,
    n_ctx=2048,             # total context window if supported
    max_tokens=1000,        # allow up to 1000 new tokens per call
    temperature=0.3,        # more deterministic sampling
    top_p=0.8,              # narrower nucleus
    repetition_penalty=1.1,
    do_sample=True,
    callback_manager=callback_manager,
    verbose=False,          # suppress llama_cpp logs
)
# Out:
# /opt/nebula/myllm/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3490: UserWarning: WARNING! repetition_penalty is not default parameter.
#                 repetition_penalty was transferred to model_kwargs.
#                 Please confirm that repetition_penalty is what you intended.
#   if await self.run_code(code, result, async_=asy):
# /opt/nebula/myllm/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3490: UserWarning: WARNING! do_sample is not default parameter.
#                 do_sample was transferred to model_kwargs.
#                 Please confirm that do_sample is what you intended.
#   if await self.run_code(code, result, async_=asy):
# llama_context: n_batch is less than GGML_KQ_MASK_PAD - increasing to 64
# llama_context: n_ctx_per_seq (2048) < n_ctx_train (4096) -- the full capacity of the model will not be utilized

# %%
# Cell 4 — Build a single few-shot ChatPromptTemplate
# ──────────────────────────────────────────────────────
system = SystemMessagePromptTemplate.from_template(
    """You are a senior cybersecurity analyst.
You will receive:
  1) A one-sentence template with placeholders.
  2) A list of possible values for each placeholder.

Your job:
  • Fill in the template with actual values.
  • Then write a structured incident report, divided into four sections:
      A. Background & Context
      B. Vulnerability & Exploit Details
      C. Observed Impact & Affected Systems
      D. Remediation & Recommendations

For each section, write **at least two complete sentences** (3–4 sentences preferred). Use concrete, professional language. Do NOT include the words “Template:” or “Values:” in your final output."""
)

human = HumanMessagePromptTemplate.from_template(
    # ——— Few-shot Example ———
    "Example:\n"
    "Template: The CVE-2023-3695 vulnerability in Windows Print Spooler was exploited by UNC1151.\n"
    "Values:\n"
    "  vuln: CVE-2023-3695\n"
    "  product: Windows Print Spooler\n"
    "  apt: UNC1151\n\n"
    "FILL + REPORT:\n"
    "The CVE-2023-3695 vulnerability in Windows Print Spooler was exploited by UNC1151.\n"
    "A. Background & Context: In mid-July 2023, Microsoft disclosed CVE-2023-3695—a remote code execution flaw in the Windows Print Spooler service. The flaw has existed in various Windows Server and client OS versions for over three years before discovery. Security researchers observed UNC1151 conducting reconnaissance activities on vulnerable print servers in multiple financial institutions.\n"
    "B. Vulnerability & Exploit Details: UNC1151 leveraged a crafted print job that overflowed a buffer within the Print Spooler’s RPC interface. The attackers then deployed a custom shellcode to gain SYSTEM-level privileges. They used this foothold to drop a signed malicious driver, ensuring persistence across reboots.\n"
    "C. Observed Impact & Affected Systems: Affected systems included dozens of domain-joined servers and workstations across at least three banking networks. Sensitive files—account ledgers and transaction logs—were encrypted, causing two days of service outages. Forensic logs show lateral movement to back-office file shares.\n"
    "D. Remediation & Recommendations: Organizations should immediately apply Microsoft’s July 2023 security update to all print spooler endpoints. Network segmentation should isolate print servers from sensitive directories. Additionally, implement least-privilege printing controls and monitor RPC calls for anomalous buffer-overflow patterns.\n\n"
    "# Now it’s your turn:\n"
    "Template: {template}\n"
    "Values:\n"
    "{values}\n\n"
    "FILL + REPORT:"
)

# simply drop input_variables – it will infer ["template","values"] because those are the only un-escaped braces
prompt = ChatPromptTemplate.from_messages([system, human])  

chain = LLMChain(llm=llm, prompt=prompt, verbose=False)
#print("ℹ️  Re-created `chain` in this kernel session.")

# %%
# Cell 5 — Generate, write .txt, add xattr if DoD, embed & store in Chroma
# ────────────────────────────────────────────────────────────────────────

n_docs     = 25
output_dir = "../../llm/synthetic_data"
os.makedirs(output_dir, exist_ok=True)

# Prepare 30 metadata tag names
METADATA_TAGS = [
    "classification",
    "classification_level",
    "originator_id",
    "data_type",
    "sensitivity",
    "transfer_control",
    "data_owner",
    "data_steward",
    "dissemination_control",
    "release_authority",
    "document_type",
    "teaming_partner",
    "handling_descriptor",
    "distribution_statement",
    "sci_control",
    "caveats",
    "ps_percent_complete",
    "point_of_contact",
    "report_version",
    "system_of_record",
    "citation",
    "related_doc",
    "platform",
    "environment",
    "operation_name",
    "mission_area",
    "geo_scope",
    "cyber_domain",
    "policy_impact",
    "audit_trail",
]

# init embedder + Chroma
embedder      = SentenceTransformer("all-MiniLM-L6-v2")
chromaclient  = chromadb.Client()
try:
    collection = chromaclient.create_collection(name="cyber_synth2")
except Exception as e:
    if "already exists" in str(e):
        collection = chromaclient.get_collection(name="cyber_synth2")
    else:
        raise

for i in range(n_docs):
    tpl, slot2label = random.choice(templates)

    # build a real values block
    vals_str = "\n".join(
        f"  {slot}: {random.choice(values[slot])}"
        for slot in slot2label.keys()
    )

    # generate
    report = chain.predict(
        template=tpl,
        values=vals_str,
        max_tokens=1000
    ).strip()

    if not report:
        print(f"⚠️  Empty response for doc {i}, retrying…")
        continue

    # write .txt
    uid       = f"doc_{i}_{uuid.uuid4().hex[:8]}"
    file_path = os.path.join(output_dir, uid + ".txt")
    with open(file_path, "w", encoding="utf-8") as fp:
        fp.write(report)

       # --- NEW: attach 30 synthetic xattr tags to every file ---
    xattrs = xattr.xattr(file_path)
    for tag in METADATA_TAGS:
        value_obj = {
            "doc_id": uid,
            "tag": tag,
            "value": fake.word()
        }
        xattrs[f"user.{tag}"] = json.dumps(value_obj).encode("utf-8")

    # embed & add to Chroma
    emb = embedder.encode(report)
    collection.add(
        documents=[report],
        embeddings=[emb],
        ids=[uid],
    )

    print(f"✅ [{i+1}/{n_docs}] wrote {uid}.txt")

print("Wrote file and set 30 xattrs → now verify on the CLI:")
print(f"  getfattr -d {file_path}")
# Out:
# A new strain of Zeus malware was seen in Sweden.✅ [1/25] wrote doc_0_96543947.txt
#
# A DDoS attack targeted Preston, Burns and Williams using the Ryuk backdoor.
# A. Background & Context: On August 15, 2023, Preston, Burns and Williams reported a distributed denial-of-service (DDoS) attack that lasted for three hours. The company’s IT team observed suspicious network traffic originating from an external IP address. Upon further investigation, they discovered the Ryuk backdoor had been installed on their network.
# B. Vulnerability & Exploit Details: The Ryuk malware was deployed through a phishing email campaign. Attackers used a malicious Word document to trick employees into opening it, allowing the payload to execute and establish persistence. Once inside, the attackers leveraged the DDoS capabilities of the Ryuk backdoor to overwhelm Preston, Burns and Williams’ network infrastructure.
# C. Observed Impact & Affected Systems: The DDoS attack resulted in a complete outage of the company’s email and web servers for three hours. No sensitive data was compromised, but the incident highlighted the importance of robust security measures to mitigate such threats.
# D. Remediation & Recommendations: Preston, Burns and Williams should implement additional security controls, including training employees on phishing awareness and implementing a network segmentation strategy. The company should also consider investing in DDoS protection services to prevent future attacks of this nature.✅ [2/25] wrote doc_1_07a093e8.txt
#
# A new strain of Zeus malware was seen in Guernsey.
# A. Background & Context: In early August 2023, security researchers detected a novel variant of the Zeus Trojan in the Channel Islands. The malware was found to be distributed via phishing emails with customized lures targeting local businesses and financial institutions.
# B. Vulnerability & Exploit Details: The new strain exploits CVE-2023-3695, a previously undiscovered remote code execution flaw in the Windows Print Spooler service. Attackers used a crafted print job to overflow a buffer within the Print Spooler’s RPC interface, allowing them to execute malicious shellcode and gain SYSTEM-level privileges.
# C. Observed Impact & Affected Systems: The malware infected 20 systems across five organizations in the Guernsey financial sector. Infected systems included a mix of Windows Server and client OS versions, with at least one system running an unpatched version of Print Spooler.
# D. Remediation & Recommendations: Organizations should immediately apply Microsoft’s July 2023 security update to all print spooler endpoints. Implementing network segmentation to isolate print servers from sensitive directories is also recommended. Additionally, enforce least-privilege printing controls and monitor RPC calls for anomalous buffer-overflow patterns.✅ [3/25] wrote doc_2_f41f2d70.txt
#
# Tyler Thomas from Vasquez-Morales discovered a zero-day CVE-2019-7913 vulnerability in the Windows Print Spooler service.✅ [4/25] wrote doc_3_44023dfc.txt
#
# A phishing attack targeted Jones, Castillo and Vargas using the TrickBot backdoor.
# A. Background & Context: On August 10th, 2023, our security team detected an increase in successful phishing attempts against Jones, Castillo and Vargas. The emails contained malicious links that, when clicked, downloaded a malicious payload from a remote server. This payload was identified as TrickBot, a highly modular backdoor with a history of targeting financial institutions.
# B. Vulnerability & Exploit Details: TrickBot exploited a previously unknown vulnerability in Microsoft Office to execute arbitrary code on the victim’s machine. The attackers used this vulnerability to gain persistence and move laterally within the network.
# C. Observed Impact & Affected Systems: The attack affected 20 workstations across three branch offices, resulting in data exfiltration of sensitive customer information. Forensic analysis revealed that the attackers accessed a database containing personal financial data, including credit card numbers and account balances.
# D. Remediation & Recommendations: Implement two-factor authentication for all email accounts, especially those with access to sensitive data. Conduct regular security training for employees to recognize and report phishing attempts. Review and update incident response procedures to address TrickBot infections.✅ [5/25] wrote doc_4_f57aa897.txt
#
# A SQL injection attack targeted Cervantes-Alvarez using TrickBot.
# A. Background & Context: On 15 August 2023, security analysts detected an SQL injection attempt on the company’s web application. The attacker exploited a vulnerability in the login page to execute arbitrary database queries, potentially exposing sensitive customer data.
# B. Vulnerability & Exploit Details: TrickBot was used to inject malicious SQL code into the application’s database. This allowed the attacker to extract customer information, including names, addresses, and financial data. The attacker also modified database structures, potentially leading to future security issues.
# C. Observed Impact & Affected Systems: The attack affected 150 customers, resulting in a loss of trust and potential legal liability for the company. Forensic analysis revealed that the attacker gained access through a vulnerable third-party library used in the application’s development.
# D. Remediation & Recommendations: Cervantes-Alvarez should immediately address the identified vulnerability by patching or replacing the affected library. Additionally, they should implement security measures to prevent future SQL injection attacks, such as input validation and limiting database privileges. The company should also inform affected customers of the incident and provide them with guidance on how to protect their personal information.✅ [6/25] wrote doc_5_8ef086e7.txt
#
# Moore, Schultz and Woods alerted its users of a potential phishing attack yesterday.
# A. Background & Context: Yesterday evening, Moore, Schultz and Woods (MSW) informed customers of an ongoing phishing campaign targeting their email accounts. The attackers used customized lures to trick employees into divulging sensitive information or clicking malicious links.
# B. Vulnerability & Exploit Details: Phishers leveraged a compromised legitimate domain to send tailored emails with malicious attachments or links. These messages appeared to originate from a trustworthy source, such as a colleague or vendor, and contained urgent content to create a sense of urgency.
# C. Observed Impact & Affected Systems: MSW reported that at least 20 employees had interacted with the phishing emails, resulting in several successful password reset requests. The attackers likely gained access to employee email accounts, potentially exposing sensitive information such as financial data or customer records.
# D. Remediation & Recommendations: Organizations should implement a robust phishing training program for employees and regularly monitor their email accounts for suspicious activity. Implement two-factor authentication (2FA) to prevent password reset attacks, and ensure that all employees use strong, unique passwords.✅ [7/25] wrote doc_6_362e87b1.txt
#
# A new strain of LockBit ransomware was seen in Kazakhstan.
# A. Background & Context: In early August 2023, security researchers detected a novel strain of the LockBit ransomware in the wild. The malware was observed targeting small businesses and critical infrastructure organizations across Kazakhstan. This is the first sighting of LockBit in Central Asia.
# B. Vulnerability & Exploit Details: Initial access was gained through a phishing email containing a malicious Word document. Once opened, the document exploited a recently discovered zero-day vulnerability in Microsoft Office to execute malicious code. The attackers then used a lateral movement technique to spread the ransomware across the network.
# C. Observed Impact & Affected Systems: At least 20 organizations were affected, with some experiencing complete data loss. The attackers demanded a ransom in Bitcoin, threatening to leak sensitive information if their demands were not met.
# D. Remediation & Recommendations: Organizations should immediately implement Microsoft’s August 2023 security patch for Office to mitigate the zero-day vulnerability. Implement a robust training program to educate employees on recognizing and reporting phishing attempts. Regularly back up critical data to prevent complete loss in case of an attack.✅ [8/25] wrote doc_7_c5d8d58b.txt
#
# The CVE-2007-5115 vulnerability in WordPress was exploited by Sandworm Team.
# A. Background & Context: In early 2023, a previously unknown vulnerability (CVE-2007-5115) was discovered in the WordPress content management system. The flaw allows attackers to execute arbitrary code on affected sites via a crafted comment. Sandworm Team, an advanced persistent threat actor, has been observed exploiting this weakness in targeted attacks against high-profile organizations.
# B. Vulnerability & Exploit Details: Sandworm Team leveraged a specially crafted comment to overflow a buffer within WordPress’s comment processing function. The attackers then deployed their custom PHP code, granting them remote access to the affected site. They used this foothold to move laterally across the network and compromise sensitive data.
# C. Observed Impact & Affected Systems: At least 12 organizations in the financial sector have been hit by this exploit, resulting in the exfiltration of sensitive data. Forensic analysis revealed that attackers gained access to over 100,000 files containing personally identifiable information (PII).
# D. Remediation & Recommendations: Implementing WordPress updates and plugins should be a top priority for organizations at risk. Additionally, implementing security measures such as two-factor authentication, restricting login attempts, and monitoring for suspicious activity can help prevent future attacks.✅ [9/25] wrote doc_8_858492dd.txt
#
# Martin-Weaver alerted its users of a potential DDoS attack yesterday.
# A. Background & Context: Martin-Weaver, a leading provider of cybersecurity services, detected unusual traffic patterns on their clients’ networks yesterday evening. The traffic peaked at 10 Gbps and lasted for over an hour. Security analysts believe the traffic may have been part of a distributed denial-of-service (DDoS) attack.
# B. Vulnerability & Exploit Details: Martin-Weaver’s security team is investigating the source of the traffic, which appears to be coming from multiple IP addresses across different countries. The team suspects that the attackers may have exploited a vulnerability in a popular web application or service.
# C. Observed Impact & Affected Systems: So far, no systems have been taken offline, but some clients have reported slow network performance. Martin-Weaver is working with affected clients to identify the root cause of the issue and implement mitigations.
# D. Remediation & Recommendations: Organizations should ensure they are running the latest software updates and security patches. They should also consider implementing DDoS protection services to shield their networks from these types of attacks. Additionally, organizations should prioritize network segmentation and intrusion detection systems to quickly identify and respond to potential threats.✅ [10/25] wrote doc_9_d5cc8dfc.txt
#
# Vaughn, Li and Braun alerted its users of a potential ransomware campaign yesterday.
# A. Background & Context: Vaughn, Li and Braun detected unusual network activity on their systems late last week. Upon further investigation, they discovered a ransomware payload had been deployed across several departments. The attackers exploited CVE-2023-3695 in the Windows Print Spooler service to gain initial access.
# B. Vulnerability & Exploit Details: The attackers leveraged a crafted print job that overflowed a buffer within the Print Spooler’s RPC interface. This allowed them to execute malicious code with SYSTEM-level privileges, deploying a custom ransomware payload.
# C. Observed Impact & Affected Systems: The attack affected over 100 employees across multiple departments, encrypting sensitive files and causing significant disruption to business operations. Forensic analysis revealed the attackers exfiltrated sensitive data before encryption.
# D. Remediation & Recommendations: Vaughn, Li and Braun should immediately apply Microsoft’s July 2023 security update to all print spooler endpoints. They should also implement least-privilege printing controls and monitor RPC calls for anomalous buffer-overflow patterns. Additionally, they should conduct a thorough incident response exercise to ensure readiness for future attacks.✅ [11/25] wrote doc_10_0f22d5e7.txt
#
# A new strain of Ryuk was seen in Tuvalu.
# A. Background & Context: In recent weeks, security researchers detected a surge in Ryuk ransomware attacks across the Pacific region, including Tuvalu. The malware is known for its sophisticated evasion techniques and high encryption strength, making it a significant threat to organizations worldwide.
# B. Vulnerability & Exploit Details: Ryuk typically exploits vulnerabilities in unpatched applications or utilizes phishing campaigns to trick users into opening malicious attachments. Once executed, the ransomware encrypts critical files and demands payment in Bitcoin for decryption keys.
# C. Observed Impact & Affected Systems: Tuvalu’s healthcare system was among those affected by the new Ryuk strain. The attack resulted in the encryption of sensitive patient data, including medical records and prescription information. Although no patient data was leaked, the incident highlights the urgent need for robust cybersecurity measures to protect against ransomware threats.
# D. Remediation & Recommendations: Organizations should prioritize implementing robust security protocols, such as regular software updates and employee training on safe computing practices. Regular backups of critical data can also help minimize the impact of a potential Ryuk attack. Additionally, organizations should consider investing in advanced cybersecurity solutions, such as AI-powered threat detection tools, to stay ahead of emerging threats like Ryuk.✅ [12/25] wrote doc_11_5a76cd09.txt
#
# A new strain of Ryuk was seen in Moldova.
# A. Background & Context: In early August 2023, our threat hunting team detected a novel version of the Ryuk ransomware in several Moldovan organizations. The malware’s codebase shows significant changes compared to previous iterations, indicating a recent development or customization.
# B. Vulnerability & Exploit Details: The new strain leverages a previously unknown vulnerability (CVE-2023-4567) in the Windows Installer Service. This flaw allows attackers to execute arbitrary code as the user, bypassing UAC protections.
# C. Observed Impact & Affected Systems: At least 12 organizations were affected, including a major telecom provider and several hospitals. The malware encrypted sensitive data, disrupting operations for over 48 hours. Forensic analysis revealed the attackers exfiltrated sensitive data before encryption.
# D. Remediation & Recommendations: Organizations should immediately apply Microsoft’s August 2023 security patch to all affected systems. Additionally, implement network segmentation and isolate vulnerable services from the internet. Implement a robust incident response plan and conduct regular threat hunting activities to detect potential attacks early on.✅ [13/25] wrote doc_12_df0befa7.txt
#
# Yang and Sons alerted its users of a potential SQL injection attack yesterday.
# A. Background & Context: Yang and Sons, a popular e-commerce platform, detected suspicious activity on their network yesterday evening. Security analysts confirmed the presence of malware on several servers, which were likely compromised through a phishing campaign. The affected servers host sensitive customer data, including credit card information and personal details.
# B. Vulnerability & Exploit Details: The attackers exploited a known SQL injection vulnerability in Yang and Sons’ web application. This flaw allowed them to execute arbitrary database queries, potentially accessing or modifying sensitive data. The malware also installed additional backdoors for future access.
# C. Observed Impact & Affected Systems: The attackers accessed customer data from multiple countries, including credit card numbers and personal information such as full names and addresses. Yang and Sons’ servers were compromised for at least two weeks before the breach was discovered. Forensic analysis revealed that the attackers exfiltrated over 10 million records containing sensitive data.
# D. Remediation & Recommendations: Yang and Sons should immediately implement security measures to prevent future SQL injection attacks, such as input validation and parameterized queries. The company should also conduct a thorough incident response exercise to assess the breach’s impact and develop a plan for mitigating it. Additionally, customers are advised to change their passwords and monitor their accounts for suspicious activity.✅ [14/25] wrote doc_13_d3508e8a.txt
#
# Mark Coleman from Ochoa, Keller and Phillips discovered a zero-day vulnerability in Microsoft Office.
# A. Background & Context: On August 15, 2023, security analyst Mark Coleman at Ochoa, Keller and Phillips identified an unreported flaw in Microsoft Office. The vulnerability exists in the WordPad application and allows for arbitrary code execution if a malicious document is opened.
# B. Vulnerability & Exploit Details: An attacker can craft a specially designed Word document that, when opened, overwrites memory with malicious code. This exploits a buffer overflow in the WordPad rendering engine. The vulnerability affects all supported versions of Microsoft Office, including Windows 10 and macOS.
# C. Observed Impact & Affected Systems: Preliminary analysis suggests that this zero-day flaw has been actively exploited by advanced persistent threat (APT) actors in targeted attacks against government agencies and Fortune 500 companies. Proof-of-concept code is already circulating on underground forums.
# D. Remediation & Recommendations: Organizations should immediately apply Microsoft’s emergency patch until a more comprehensive fix can be developed. Additionally, implement least-privilege document rendering controls and conduct regular security audits to detect suspicious activity.✅ [15/25] wrote doc_14_89b9a78d.txt
#
# A new strain of LockBit ransomware was seen in Tajikistan.
# A. Background & Context: In the past week, security researchers detected a previously unknown variant of LockBit ransomware in Tajikistan. The malware has been observed targeting critical infrastructure, including government agencies and essential services. The attackers are demanding payment in Bitcoin to restore encrypted data.
# B. Vulnerability & Exploit Details: The new variant of LockBit uses a novel exploitation technique to evade detection by traditional sandboxes and antivirus software. It leverages a previously unknown vulnerability in the Windows Print Spooler service, which is commonly used on Tajikistan-based systems.
# C. Observed Impact & Affected Systems: At least 10 government agencies and critical infrastructure providers have been affected by the attack, resulting in significant disruption to essential services. The attackers have threatened to escalate their attacks if their demands are not met within 72 hours.
# D. Remediation & Recommendations: Organizations should immediately apply Microsoft’s July 2023 security update to all print spooler endpoints in Tajikistan. Additionally, they should ensure that their systems are up-to-date with the latest patches and software updates. Network segmentation should be implemented to isolate affected systems from the rest of the network. Finally, organizations should consider implementing a ransomware response plan to minimize the impact of future attacks.✅ [16/25] wrote doc_15_bed47bf2.txt
#
# A new strain of Zeus malware was seen in Saint Martin.
# A. Background & Context: In early August 2023, a new variant of the Zeus trojan was detected in the Caribbean island of Saint Martin. The malware is believed to have been spread via phishing emails with malicious attachments.
# B. Vulnerability & Exploit Details: The new strain uses a previously unknown exploit to bypass security controls and gain persistence on infected systems. Once installed, the malware can steal login credentials and monitor user activity.
# C. Observed Impact & Affected Systems: Initial reports indicate that at least 20 Saint Martin-based organizations have been affected, including a major bank and several small businesses. The malware has been observed exfiltrating sensitive data, including financial records and customer databases.
# D. Remediation & Recommendations: Organizations in Saint Martin should immediately implement security measures to prevent the spread of Zeus malware. This includes training employees on phishing awareness and implementing email filtering solutions to detect and block malicious attachments. Additionally, organizations should consider conducting a thorough incident response exercise to prepare for potential future attacks.✅ [17/25] wrote doc_16_ca9e078b.txt
#
# A new strain of Zeus malware was seen in Korea.
# A. Background & Context: In mid-July 2023, security researchers detected a new variant of the Zeus trojan in Korean cybercrime forums. The malware is designed to steal login credentials and financial information from infected computers.
# B. Vulnerability & Exploit Details: The new strain uses a novel exploitation technique to bypass existing defenses, including anti-virus software and firewalls. The attackers use a customized phishing lure to trick users into downloading the malware. Once installed, Zeus can steal login credentials for popular email and social media accounts.
# C. Observed Impact & Affected Systems: The malware has infected over 100 computers across several Korean universities and businesses. The attackers have used the stolen credentials to gain access to sensitive data, including student records and financial information.
# D. Remediation & Recommendations: Organizations should educate users on safe computing practices and implement two-factor authentication for all accounts. Network defenders should monitor network traffic for suspicious activity and deploy intrusion detection systems to detect and block the malware’s communication channels.✅ [18/25] wrote doc_17_6369f22a.txt
#
# Johnson, Taylor and Adams alerted its users of a potential SQL injection attack yesterday.
# A. Background & Context: Yesterday evening, Johnson, Taylor and Adams informed its customers of a potential security incident involving unauthorized access to sensitive data. The company detected suspicious network activity associated with an SQL injection vulnerability in one of their web applications.
# B. Vulnerability & Exploit Details: An attacker exploited a SQL injection flaw in the application’s login functionality, allowing them to execute arbitrary database queries. This led to unauthorized access to sensitive data, including customer records and financial information.
# C. Observed Impact & Affected Systems: The compromised system contained personal data for approximately 10,000 customers, including names, addresses, phone numbers, and financial information. Although the company did not report any instances of fraud or misuse, it has taken steps to contain the incident and prevent future attacks.
# D. Remediation & Recommendations: Johnson, Taylor and Adams recommended that affected customers change their passwords and monitor their accounts for suspicious activity. The company also advised its security team to conduct a thorough review of its web applications and databases to identify any additional vulnerabilities.✅ [19/25] wrote doc_18_be3862ca.txt
#
# Mark Harper from Cervantes-Alvarez discovered a zero-day vulnerability in the Windows Kernel.✅ [20/25] wrote doc_19_d228dad8.txt
#
# April Holmes from Douglas, Jenkins and Hudson discovered a zero-day vulnerability in Microsoft Office.
# A. Background & Context: In early January 2023, April Holmes, a security analyst at Douglas, Jenkins and Hudson, identified an unpatched flaw in Microsoft Office that could allow arbitrary code execution on affected systems. The vulnerability resides in the Office suite’s XML-based file format, which is used for document rendering.
# B. Vulnerability & Exploit Details: The vulnerability arises from a buffer overflow in the Office suite’s XML parser. An attacker could exploit this flaw by sending a specially crafted XML file to a target user. Once opened, the malicious file would execute arbitrary code on the victim’s system with full privileges.
# C. Observed Impact & Affected Systems: The vulnerability has been observed in all recent versions of Microsoft Office, including Windows and macOS installations. A proof-of-concept exploit was successful in executing malicious code on a test environment within 24 hours of discovery.
# D. Remediation & Recommendations: Organizations should immediately apply the January 2023 patch from Microsoft to mitigate this vulnerability. Additionally, implement least-privilege office settings and restrict document execution capabilities for all users.
#
# Please fill in the template with actual values and write a structured incident report based on the provided scenario.✅ [21/25] wrote doc_20_5e0a265f.txt
#
# Jonathan Mcguire from Chandler and Sons discovered a zero-day vulnerability in the Windows Print Spooler service.✅ [22/25] wrote doc_21_25f255b3.txt
#
# The CVE-2007-6736 vulnerability in OpenSSL was exploited by APT28.
# A. Background & Context: In March 2007, a critical buffer overflow flaw (CVE-2007-6736) was discovered in OpenSSL versions prior to 0.9.8r. The vulnerability allowed attackers to execute arbitrary code on affected systems.
# B. Vulnerability & Exploit Details: APT28 leveraged a crafted certificate to exploit the buffer overflow flaw, leading to remote code execution. The attackers then used their newfound privileges to move laterally within the compromised network and exfiltrate sensitive data.
# C. Observed Impact & Affected Systems: APT28’s campaign targeted several major financial institutions, resulting in a significant loss of intellectual property and revenue. Forensic analysis revealed that the attackers maintained persistence on affected systems for over six months before discovery.
# D. Remediation & Recommendations: Organizations should immediately apply OpenSSL security updates to all affected systems. Implementing network segmentation can help isolate vulnerable systems and limit potential lateral movement. Additionally, implement a robust logging and monitoring solution to detect and alert on suspicious certificate-based activity.✅ [23/25] wrote doc_22_09ca34a0.txt
#
# Clark, Smith and Pearson alerted its users of a potential SQL injection yesterday.
# A. Background & Context: Clark, Smith and Pearson received an anonymous tip regarding suspicious database access patterns. Upon investigation, they discovered a malicious actor attempting to exploit an unpatched SQL injection vulnerability. The attacker managed to bypass security controls and gain unauthorized access to sensitive data.
# B. Vulnerability & Exploit Details: The attacker leveraged a SQL injection flaw in the company’s web application, which allowed them to execute arbitrary code on the database server. This led to the exfiltration of sensitive data, including customer records and financial information.
# C. Observed Impact & Affected Systems: The compromised systems included several databases containing sensitive data, such as customer records and financial information. The attacker managed to exfiltrate a significant amount of data before the security team detected and contained the incident.
# D. Remediation & Recommendations: Clark, Smith and Pearson should immediately apply the recommended patches to address the SQL injection vulnerability. Additionally, they should conduct a thorough risk assessment to identify any other potential vulnerabilities in their web application and database infrastructure. Finally, they should implement additional security controls, such as data encryption and access controls, to prevent similar incidents from occurring in the future.✅ [24/25] wrote doc_23_cd92b448.txt
#
# The CVE-2015-2429 vulnerability in Windows 10 was exploited by APT29.
# A. Background & Context: In early February 2015, Microsoft disclosed CVE-2015-2429—a remote code execution flaw in the Windows 10 kernel. The vulnerability allowed attackers to execute arbitrary code with kernel privileges by manipulating the function pointer of a kernel-mode driver.
# B. Vulnerability & Exploit Details: APT29 exploited CVE-2015-2429 via a spear-phishing email campaign targeting high-value users in the financial sector. The attackers crafted a malicious Word document that, when opened, executed a carefully designed RTF payload that abused the vulnerability to gain kernel-level access.
# C. Observed Impact & Affected Systems: Infected systems included several banks and credit unions across North America. Attackers exfiltrated sensitive data, including account numbers and personal identification information, for at least 12 hours before detection.
# D. Remediation & Recommendations: Organizations should immediately apply Microsoft’s February 2015 security update to all Windows 10 endpoints. Additionally, implement training programs to educate users about the dangers of opening unsolicited emails and attachments. Finally, conduct regular security audits to identify and address any additional vulnerabilities in the network.✅ [25/25] wrote doc_24_619c2b7b.txt
# Wrote file and set 30 xattrs → now verify on the CLI:
#   getfattr -d ../../llm/synthetic_data/doc_24_619c2b7b.txt
