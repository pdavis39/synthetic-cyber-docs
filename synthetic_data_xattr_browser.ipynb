# %%
import os
import pwd
import grp
import time
import xattr
from langchain.chains import RetrievalQA

# %%
# ANSI escape sequences for colors
CYAN = '\033[36m'
YELLOW = '\033[33m'
BLUE = '\033[34m'
GREEN = '\033[32m'
RESET = '\033[0m'

# %%
def list_xattrs_of_file(file_path):
    """
    List a file's extended attributes with colored output, including metadata similar to 'ls -l' command.

    Parameters:
    file_path (str): The path to the file whose xattrs will be listed.

    Returns:
    None
    """
    # Check if the file exists
    if not os.path.exists(file_path):
        print(f"The file '{file_path}' does not exist.")
        return
    if not os.path.isfile(file_path):
        print(f"The path '{file_path}' is not a file.")
        return

    # Get file stats
    stats = os.stat(file_path)
    # Calculate block size (assuming 512 bytes per block)
    block_size = stats.st_blocks * 512
    # Get file permissions
    permissions = oct(stats.st_mode)[-3:]
    # Get number of links
    links = stats.st_nlink
    # Get owner name
    owner = pwd.getpwuid(stats.st_uid).pw_name
    # Get group name
    group = grp.getgrgid(stats.st_gid).gr_name
    # Get file size in bytes
    size = stats.st_size
    # Get last modification time
    mtime = time.strftime('%b %d %H:%M', time.localtime(stats.st_mtime))

    # Print file metadata as key-value pairs with blue keys and green values
    print(f"{BLUE}file_name{RESET}: {GREEN}{os.path.basename(file_path)}{RESET}")
    print(f"{BLUE}block_size{RESET}: {GREEN}{block_size}{RESET}")
    print(f"{BLUE}permission{RESET}: {GREEN}{permissions}{RESET}")
    print(f"{BLUE}links{RESET}: {GREEN}{links}{RESET}")
    print(f"{BLUE}owner{RESET}: {GREEN}{owner}{RESET}")
    print(f"{BLUE}group{RESET}: {GREEN}{group}{RESET}")
    print(f"{BLUE}size{RESET}: {GREEN}{size}{RESET}")
    print(f"{BLUE}mod_time{RESET}: {GREEN}{mtime}{RESET}")

    try:
        # Get the list of xattr keys for the file
        attrs = xattr.listxattr(file_path)
        # Retrieve the value for each xattr key
        xattrs_dict = {key: xattr.getxattr(file_path, key) for key in attrs}
    except (IOError, PermissionError) as e:
        print(f"Could not read xattrs for '{os.path.basename(file_path)}': {e}")
        xattrs_dict = {}

    # Pretty-print the file's xattrs with color
    if xattrs_dict:
        print(f"{CYAN}plus xattr metadata{RESET}:")
        for key, value in xattrs_dict.items():
            # Decode the value for better readability if it's binary data
            try:
                value = value.decode('utf-8')
            except UnicodeDecodeError:
                value = value.hex()
            # Print key in cyan and value in yellow
            print(f"  {CYAN}{key}{RESET}: {YELLOW}{value}{RESET}")
    else:
        print(f"{CYAN}plus xattr metadata{RESET}: None")
    print()  # Add an empty line for better separation

# %%
synthetic_data ='/nfs/enclave_a/llm/synthetic_data'

# %%
if not os.path.isdir(synthetic_data):
    raise RuntimeError(f"Directory not found: {synthetic_data}")

for entry in sorted(os.listdir(synthetic_data)):
    path = os.path.join(synthetic_data, entry)
    if os.path.isfile(path):
        list_xattrs_of_file(path)
# Out:
# file_name: doc_0_96543947.txt
# block_size: 0
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 48
# mod_time: Aug 26 15:31
# plus xattr metadata:
#   user.classification_level: {"doc_id": "doc_0_96543947", "tag": "classification_level", "value": "read"}
#   user.originator_id: {"doc_id": "doc_0_96543947", "tag": "originator_id", "value": "treatment"}
#   user.data_type: {"doc_id": "doc_0_96543947", "tag": "data_type", "value": "over"}
#   user.sensitivity: {"doc_id": "doc_0_96543947", "tag": "sensitivity", "value": "since"}
#   user.transfer_control: {"doc_id": "doc_0_96543947", "tag": "transfer_control", "value": "tend"}
#   user.data_owner: {"doc_id": "doc_0_96543947", "tag": "data_owner", "value": "whatever"}
#   user.data_steward: {"doc_id": "doc_0_96543947", "tag": "data_steward", "value": "next"}
#   user.dissemination_control: {"doc_id": "doc_0_96543947", "tag": "dissemination_control", "value": "great"}
#   user.release_authority: {"doc_id": "doc_0_96543947", "tag": "release_authority", "value": "part"}
#   user.document_type: {"doc_id": "doc_0_96543947", "tag": "document_type", "value": "popular"}
#   user.teaming_partner: {"doc_id": "doc_0_96543947", "tag": "teaming_partner", "value": "special"}
#   user.handling_descriptor: {"doc_id": "doc_0_96543947", "tag": "handling_descriptor", "value": "major"}
#   user.distribution_statement: {"doc_id": "doc_0_96543947", "tag": "distribution_statement", "value": "group"}
#   user.sci_control: {"doc_id": "doc_0_96543947", "tag": "sci_control", "value": "pressure"}
#   user.caveats: {"doc_id": "doc_0_96543947", "tag": "caveats", "value": "wish"}
#   user.ps_percent_complete: {"doc_id": "doc_0_96543947", "tag": "ps_percent_complete", "value": "economic"}
#   user.point_of_contact: {"doc_id": "doc_0_96543947", "tag": "point_of_contact", "value": "only"}
#   user.report_version: {"doc_id": "doc_0_96543947", "tag": "report_version", "value": "commercial"}
#   user.system_of_record: {"doc_id": "doc_0_96543947", "tag": "system_of_record", "value": "since"}
#   user.citation: {"doc_id": "doc_0_96543947", "tag": "citation", "value": "money"}
#   user.related_doc: {"doc_id": "doc_0_96543947", "tag": "related_doc", "value": "many"}
#   user.platform: {"doc_id": "doc_0_96543947", "tag": "platform", "value": "decade"}
#   user.environment: {"doc_id": "doc_0_96543947", "tag": "environment", "value": "detail"}
#   user.operation_name: {"doc_id": "doc_0_96543947", "tag": "operation_name", "value": "save"}
#   user.mission_area: {"doc_id": "doc_0_96543947", "tag": "mission_area", "value": "single"}
#   user.geo_scope: {"doc_id": "doc_0_96543947", "tag": "geo_scope", "value": "such"}
#   user.cyber_domain: {"doc_id": "doc_0_96543947", "tag": "cyber_domain", "value": "middle"}
#   user.policy_impact: {"doc_id": "doc_0_96543947", "tag": "policy_impact", "value": "white"}
#   user.audit_trail: {"doc_id": "doc_0_96543947", "tag": "audit_trail", "value": "high"}
#   user.classification: SECRET
#
# file_name: doc_10_0f22d5e7.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1336
# mod_time: Aug 26 15:33
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_10_0f22d5e7", "tag": "classification", "value": "board"}
#   user.classification_level: {"doc_id": "doc_10_0f22d5e7", "tag": "classification_level", "value": "off"}
#   user.originator_id: {"doc_id": "doc_10_0f22d5e7", "tag": "originator_id", "value": "rock"}
#   user.data_type: {"doc_id": "doc_10_0f22d5e7", "tag": "data_type", "value": "part"}
#   user.sensitivity: {"doc_id": "doc_10_0f22d5e7", "tag": "sensitivity", "value": "early"}
#   user.transfer_control: {"doc_id": "doc_10_0f22d5e7", "tag": "transfer_control", "value": "edge"}
#   user.data_owner: {"doc_id": "doc_10_0f22d5e7", "tag": "data_owner", "value": "arrive"}
#   user.data_steward: {"doc_id": "doc_10_0f22d5e7", "tag": "data_steward", "value": "their"}
#   user.dissemination_control: {"doc_id": "doc_10_0f22d5e7", "tag": "dissemination_control", "value": "life"}
#   user.release_authority: {"doc_id": "doc_10_0f22d5e7", "tag": "release_authority", "value": "those"}
#   user.document_type: {"doc_id": "doc_10_0f22d5e7", "tag": "document_type", "value": "both"}
#   user.teaming_partner: {"doc_id": "doc_10_0f22d5e7", "tag": "teaming_partner", "value": "three"}
#   user.handling_descriptor: {"doc_id": "doc_10_0f22d5e7", "tag": "handling_descriptor", "value": "team"}
#   user.distribution_statement: {"doc_id": "doc_10_0f22d5e7", "tag": "distribution_statement", "value": "top"}
#   user.sci_control: {"doc_id": "doc_10_0f22d5e7", "tag": "sci_control", "value": "clearly"}
#   user.caveats: {"doc_id": "doc_10_0f22d5e7", "tag": "caveats", "value": "member"}
#   user.ps_percent_complete: {"doc_id": "doc_10_0f22d5e7", "tag": "ps_percent_complete", "value": "suddenly"}
#   user.point_of_contact: {"doc_id": "doc_10_0f22d5e7", "tag": "point_of_contact", "value": "her"}
#   user.report_version: {"doc_id": "doc_10_0f22d5e7", "tag": "report_version", "value": "despite"}
#   user.system_of_record: {"doc_id": "doc_10_0f22d5e7", "tag": "system_of_record", "value": "season"}
#   user.citation: {"doc_id": "doc_10_0f22d5e7", "tag": "citation", "value": "space"}
#   user.related_doc: {"doc_id": "doc_10_0f22d5e7", "tag": "related_doc", "value": "kitchen"}
#   user.platform: {"doc_id": "doc_10_0f22d5e7", "tag": "platform", "value": "audience"}
#   user.environment: {"doc_id": "doc_10_0f22d5e7", "tag": "environment", "value": "occur"}
#   user.operation_name: {"doc_id": "doc_10_0f22d5e7", "tag": "operation_name", "value": "number"}
#   user.mission_area: {"doc_id": "doc_10_0f22d5e7", "tag": "mission_area", "value": "cause"}
#   user.geo_scope: {"doc_id": "doc_10_0f22d5e7", "tag": "geo_scope", "value": "themselves"}
#   user.cyber_domain: {"doc_id": "doc_10_0f22d5e7", "tag": "cyber_domain", "value": "camera"}
#   user.policy_impact: {"doc_id": "doc_10_0f22d5e7", "tag": "policy_impact", "value": "prepare"}
#   user.audit_trail: {"doc_id": "doc_10_0f22d5e7", "tag": "audit_trail", "value": "let"}
#
# file_name: doc_11_5a76cd09.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1485
# mod_time: Aug 26 15:33
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_11_5a76cd09", "tag": "classification", "value": "wide"}
#   user.classification_level: {"doc_id": "doc_11_5a76cd09", "tag": "classification_level", "value": "plant"}
#   user.originator_id: {"doc_id": "doc_11_5a76cd09", "tag": "originator_id", "value": "career"}
#   user.data_type: {"doc_id": "doc_11_5a76cd09", "tag": "data_type", "value": "issue"}
#   user.sensitivity: {"doc_id": "doc_11_5a76cd09", "tag": "sensitivity", "value": "production"}
#   user.transfer_control: {"doc_id": "doc_11_5a76cd09", "tag": "transfer_control", "value": "design"}
#   user.data_owner: {"doc_id": "doc_11_5a76cd09", "tag": "data_owner", "value": "citizen"}
#   user.data_steward: {"doc_id": "doc_11_5a76cd09", "tag": "data_steward", "value": "heavy"}
#   user.dissemination_control: {"doc_id": "doc_11_5a76cd09", "tag": "dissemination_control", "value": "born"}
#   user.release_authority: {"doc_id": "doc_11_5a76cd09", "tag": "release_authority", "value": "trouble"}
#   user.document_type: {"doc_id": "doc_11_5a76cd09", "tag": "document_type", "value": "receive"}
#   user.teaming_partner: {"doc_id": "doc_11_5a76cd09", "tag": "teaming_partner", "value": "five"}
#   user.handling_descriptor: {"doc_id": "doc_11_5a76cd09", "tag": "handling_descriptor", "value": "push"}
#   user.distribution_statement: {"doc_id": "doc_11_5a76cd09", "tag": "distribution_statement", "value": "but"}
#   user.sci_control: {"doc_id": "doc_11_5a76cd09", "tag": "sci_control", "value": "act"}
#   user.caveats: {"doc_id": "doc_11_5a76cd09", "tag": "caveats", "value": "smile"}
#   user.ps_percent_complete: {"doc_id": "doc_11_5a76cd09", "tag": "ps_percent_complete", "value": "ground"}
#   user.point_of_contact: {"doc_id": "doc_11_5a76cd09", "tag": "point_of_contact", "value": "describe"}
#   user.report_version: {"doc_id": "doc_11_5a76cd09", "tag": "report_version", "value": "issue"}
#   user.system_of_record: {"doc_id": "doc_11_5a76cd09", "tag": "system_of_record", "value": "there"}
#   user.citation: {"doc_id": "doc_11_5a76cd09", "tag": "citation", "value": "language"}
#   user.related_doc: {"doc_id": "doc_11_5a76cd09", "tag": "related_doc", "value": "word"}
#   user.platform: {"doc_id": "doc_11_5a76cd09", "tag": "platform", "value": "push"}
#   user.environment: {"doc_id": "doc_11_5a76cd09", "tag": "environment", "value": "middle"}
#   user.operation_name: {"doc_id": "doc_11_5a76cd09", "tag": "operation_name", "value": "agreement"}
#   user.mission_area: {"doc_id": "doc_11_5a76cd09", "tag": "mission_area", "value": "born"}
#   user.geo_scope: {"doc_id": "doc_11_5a76cd09", "tag": "geo_scope", "value": "pay"}
#   user.cyber_domain: {"doc_id": "doc_11_5a76cd09", "tag": "cyber_domain", "value": "message"}
#   user.policy_impact: {"doc_id": "doc_11_5a76cd09", "tag": "policy_impact", "value": "whose"}
#   user.audit_trail: {"doc_id": "doc_11_5a76cd09", "tag": "audit_trail", "value": "final"}
#
# file_name: doc_12_df0befa7.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1233
# mod_time: Aug 26 15:33
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_12_df0befa7", "tag": "classification", "value": "expect"}
#   user.classification_level: {"doc_id": "doc_12_df0befa7", "tag": "classification_level", "value": "national"}
#   user.originator_id: {"doc_id": "doc_12_df0befa7", "tag": "originator_id", "value": "far"}
#   user.data_type: {"doc_id": "doc_12_df0befa7", "tag": "data_type", "value": "rich"}
#   user.sensitivity: {"doc_id": "doc_12_df0befa7", "tag": "sensitivity", "value": "person"}
#   user.transfer_control: {"doc_id": "doc_12_df0befa7", "tag": "transfer_control", "value": "charge"}
#   user.data_owner: {"doc_id": "doc_12_df0befa7", "tag": "data_owner", "value": "at"}
#   user.data_steward: {"doc_id": "doc_12_df0befa7", "tag": "data_steward", "value": "option"}
#   user.dissemination_control: {"doc_id": "doc_12_df0befa7", "tag": "dissemination_control", "value": "score"}
#   user.release_authority: {"doc_id": "doc_12_df0befa7", "tag": "release_authority", "value": "town"}
#   user.document_type: {"doc_id": "doc_12_df0befa7", "tag": "document_type", "value": "commercial"}
#   user.teaming_partner: {"doc_id": "doc_12_df0befa7", "tag": "teaming_partner", "value": "worker"}
#   user.handling_descriptor: {"doc_id": "doc_12_df0befa7", "tag": "handling_descriptor", "value": "along"}
#   user.distribution_statement: {"doc_id": "doc_12_df0befa7", "tag": "distribution_statement", "value": "practice"}
#   user.sci_control: {"doc_id": "doc_12_df0befa7", "tag": "sci_control", "value": "give"}
#   user.caveats: {"doc_id": "doc_12_df0befa7", "tag": "caveats", "value": "candidate"}
#   user.ps_percent_complete: {"doc_id": "doc_12_df0befa7", "tag": "ps_percent_complete", "value": "bar"}
#   user.point_of_contact: {"doc_id": "doc_12_df0befa7", "tag": "point_of_contact", "value": "assume"}
#   user.report_version: {"doc_id": "doc_12_df0befa7", "tag": "report_version", "value": "interview"}
#   user.system_of_record: {"doc_id": "doc_12_df0befa7", "tag": "system_of_record", "value": "must"}
#   user.citation: {"doc_id": "doc_12_df0befa7", "tag": "citation", "value": "significant"}
#   user.related_doc: {"doc_id": "doc_12_df0befa7", "tag": "related_doc", "value": "unit"}
#   user.platform: {"doc_id": "doc_12_df0befa7", "tag": "platform", "value": "machine"}
#   user.environment: {"doc_id": "doc_12_df0befa7", "tag": "environment", "value": "realize"}
#   user.operation_name: {"doc_id": "doc_12_df0befa7", "tag": "operation_name", "value": "Mrs"}
#   user.mission_area: {"doc_id": "doc_12_df0befa7", "tag": "mission_area", "value": "blood"}
#   user.geo_scope: {"doc_id": "doc_12_df0befa7", "tag": "geo_scope", "value": "upon"}
#   user.cyber_domain: {"doc_id": "doc_12_df0befa7", "tag": "cyber_domain", "value": "according"}
#   user.policy_impact: {"doc_id": "doc_12_df0befa7", "tag": "policy_impact", "value": "nice"}
#   user.audit_trail: {"doc_id": "doc_12_df0befa7", "tag": "audit_trail", "value": "experience"}
#
# file_name: doc_13_d3508e8a.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1605
# mod_time: Aug 26 15:33
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_13_d3508e8a", "tag": "classification", "value": "movement"}
#   user.classification_level: {"doc_id": "doc_13_d3508e8a", "tag": "classification_level", "value": "six"}
#   user.originator_id: {"doc_id": "doc_13_d3508e8a", "tag": "originator_id", "value": "catch"}
#   user.data_type: {"doc_id": "doc_13_d3508e8a", "tag": "data_type", "value": "thank"}
#   user.sensitivity: {"doc_id": "doc_13_d3508e8a", "tag": "sensitivity", "value": "across"}
#   user.transfer_control: {"doc_id": "doc_13_d3508e8a", "tag": "transfer_control", "value": "throw"}
#   user.data_owner: {"doc_id": "doc_13_d3508e8a", "tag": "data_owner", "value": "which"}
#   user.data_steward: {"doc_id": "doc_13_d3508e8a", "tag": "data_steward", "value": "authority"}
#   user.dissemination_control: {"doc_id": "doc_13_d3508e8a", "tag": "dissemination_control", "value": "least"}
#   user.release_authority: {"doc_id": "doc_13_d3508e8a", "tag": "release_authority", "value": "down"}
#   user.document_type: {"doc_id": "doc_13_d3508e8a", "tag": "document_type", "value": "word"}
#   user.teaming_partner: {"doc_id": "doc_13_d3508e8a", "tag": "teaming_partner", "value": "tell"}
#   user.handling_descriptor: {"doc_id": "doc_13_d3508e8a", "tag": "handling_descriptor", "value": "chair"}
#   user.distribution_statement: {"doc_id": "doc_13_d3508e8a", "tag": "distribution_statement", "value": "either"}
#   user.sci_control: {"doc_id": "doc_13_d3508e8a", "tag": "sci_control", "value": "federal"}
#   user.caveats: {"doc_id": "doc_13_d3508e8a", "tag": "caveats", "value": "ago"}
#   user.ps_percent_complete: {"doc_id": "doc_13_d3508e8a", "tag": "ps_percent_complete", "value": "least"}
#   user.point_of_contact: {"doc_id": "doc_13_d3508e8a", "tag": "point_of_contact", "value": "offer"}
#   user.report_version: {"doc_id": "doc_13_d3508e8a", "tag": "report_version", "value": "think"}
#   user.system_of_record: {"doc_id": "doc_13_d3508e8a", "tag": "system_of_record", "value": "set"}
#   user.citation: {"doc_id": "doc_13_d3508e8a", "tag": "citation", "value": "education"}
#   user.related_doc: {"doc_id": "doc_13_d3508e8a", "tag": "related_doc", "value": "machine"}
#   user.platform: {"doc_id": "doc_13_d3508e8a", "tag": "platform", "value": "method"}
#   user.environment: {"doc_id": "doc_13_d3508e8a", "tag": "environment", "value": "involve"}
#   user.operation_name: {"doc_id": "doc_13_d3508e8a", "tag": "operation_name", "value": "hold"}
#   user.mission_area: {"doc_id": "doc_13_d3508e8a", "tag": "mission_area", "value": "church"}
#   user.geo_scope: {"doc_id": "doc_13_d3508e8a", "tag": "geo_scope", "value": "day"}
#   user.cyber_domain: {"doc_id": "doc_13_d3508e8a", "tag": "cyber_domain", "value": "church"}
#   user.policy_impact: {"doc_id": "doc_13_d3508e8a", "tag": "policy_impact", "value": "leave"}
#   user.audit_trail: {"doc_id": "doc_13_d3508e8a", "tag": "audit_trail", "value": "man"}
#
# file_name: doc_14_89b9a78d.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1296
# mod_time: Aug 26 15:33
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_14_89b9a78d", "tag": "classification", "value": "television"}
#   user.classification_level: {"doc_id": "doc_14_89b9a78d", "tag": "classification_level", "value": "attack"}
#   user.originator_id: {"doc_id": "doc_14_89b9a78d", "tag": "originator_id", "value": "yet"}
#   user.data_type: {"doc_id": "doc_14_89b9a78d", "tag": "data_type", "value": "deal"}
#   user.sensitivity: {"doc_id": "doc_14_89b9a78d", "tag": "sensitivity", "value": "surface"}
#   user.transfer_control: {"doc_id": "doc_14_89b9a78d", "tag": "transfer_control", "value": "rise"}
#   user.data_owner: {"doc_id": "doc_14_89b9a78d", "tag": "data_owner", "value": "activity"}
#   user.data_steward: {"doc_id": "doc_14_89b9a78d", "tag": "data_steward", "value": "film"}
#   user.dissemination_control: {"doc_id": "doc_14_89b9a78d", "tag": "dissemination_control", "value": "the"}
#   user.release_authority: {"doc_id": "doc_14_89b9a78d", "tag": "release_authority", "value": "fall"}
#   user.document_type: {"doc_id": "doc_14_89b9a78d", "tag": "document_type", "value": "certain"}
#   user.teaming_partner: {"doc_id": "doc_14_89b9a78d", "tag": "teaming_partner", "value": "college"}
#   user.handling_descriptor: {"doc_id": "doc_14_89b9a78d", "tag": "handling_descriptor", "value": "week"}
#   user.distribution_statement: {"doc_id": "doc_14_89b9a78d", "tag": "distribution_statement", "value": "court"}
#   user.sci_control: {"doc_id": "doc_14_89b9a78d", "tag": "sci_control", "value": "full"}
#   user.caveats: {"doc_id": "doc_14_89b9a78d", "tag": "caveats", "value": "reduce"}
#   user.ps_percent_complete: {"doc_id": "doc_14_89b9a78d", "tag": "ps_percent_complete", "value": "somebody"}
#   user.point_of_contact: {"doc_id": "doc_14_89b9a78d", "tag": "point_of_contact", "value": "it"}
#   user.report_version: {"doc_id": "doc_14_89b9a78d", "tag": "report_version", "value": "American"}
#   user.system_of_record: {"doc_id": "doc_14_89b9a78d", "tag": "system_of_record", "value": "political"}
#   user.citation: {"doc_id": "doc_14_89b9a78d", "tag": "citation", "value": "company"}
#   user.related_doc: {"doc_id": "doc_14_89b9a78d", "tag": "related_doc", "value": "main"}
#   user.platform: {"doc_id": "doc_14_89b9a78d", "tag": "platform", "value": "himself"}
#   user.environment: {"doc_id": "doc_14_89b9a78d", "tag": "environment", "value": "some"}
#   user.operation_name: {"doc_id": "doc_14_89b9a78d", "tag": "operation_name", "value": "executive"}
#   user.mission_area: {"doc_id": "doc_14_89b9a78d", "tag": "mission_area", "value": "realize"}
#   user.geo_scope: {"doc_id": "doc_14_89b9a78d", "tag": "geo_scope", "value": "add"}
#   user.cyber_domain: {"doc_id": "doc_14_89b9a78d", "tag": "cyber_domain", "value": "little"}
#   user.policy_impact: {"doc_id": "doc_14_89b9a78d", "tag": "policy_impact", "value": "garden"}
#   user.audit_trail: {"doc_id": "doc_14_89b9a78d", "tag": "audit_trail", "value": "none"}
#
# file_name: doc_15_bed47bf2.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1493
# mod_time: Aug 26 15:33
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_15_bed47bf2", "tag": "classification", "value": "right"}
#   user.classification_level: {"doc_id": "doc_15_bed47bf2", "tag": "classification_level", "value": "future"}
#   user.originator_id: {"doc_id": "doc_15_bed47bf2", "tag": "originator_id", "value": "do"}
#   user.data_type: {"doc_id": "doc_15_bed47bf2", "tag": "data_type", "value": "charge"}
#   user.sensitivity: {"doc_id": "doc_15_bed47bf2", "tag": "sensitivity", "value": "son"}
#   user.transfer_control: {"doc_id": "doc_15_bed47bf2", "tag": "transfer_control", "value": "account"}
#   user.data_owner: {"doc_id": "doc_15_bed47bf2", "tag": "data_owner", "value": "reach"}
#   user.data_steward: {"doc_id": "doc_15_bed47bf2", "tag": "data_steward", "value": "order"}
#   user.dissemination_control: {"doc_id": "doc_15_bed47bf2", "tag": "dissemination_control", "value": "social"}
#   user.release_authority: {"doc_id": "doc_15_bed47bf2", "tag": "release_authority", "value": "society"}
#   user.document_type: {"doc_id": "doc_15_bed47bf2", "tag": "document_type", "value": "wide"}
#   user.teaming_partner: {"doc_id": "doc_15_bed47bf2", "tag": "teaming_partner", "value": "analysis"}
#   user.handling_descriptor: {"doc_id": "doc_15_bed47bf2", "tag": "handling_descriptor", "value": "itself"}
#   user.distribution_statement: {"doc_id": "doc_15_bed47bf2", "tag": "distribution_statement", "value": "pressure"}
#   user.sci_control: {"doc_id": "doc_15_bed47bf2", "tag": "sci_control", "value": "true"}
#   user.caveats: {"doc_id": "doc_15_bed47bf2", "tag": "caveats", "value": "money"}
#   user.ps_percent_complete: {"doc_id": "doc_15_bed47bf2", "tag": "ps_percent_complete", "value": "rule"}
#   user.point_of_contact: {"doc_id": "doc_15_bed47bf2", "tag": "point_of_contact", "value": "responsibility"}
#   user.report_version: {"doc_id": "doc_15_bed47bf2", "tag": "report_version", "value": "his"}
#   user.system_of_record: {"doc_id": "doc_15_bed47bf2", "tag": "system_of_record", "value": "sell"}
#   user.citation: {"doc_id": "doc_15_bed47bf2", "tag": "citation", "value": "identify"}
#   user.related_doc: {"doc_id": "doc_15_bed47bf2", "tag": "related_doc", "value": "again"}
#   user.platform: {"doc_id": "doc_15_bed47bf2", "tag": "platform", "value": "term"}
#   user.environment: {"doc_id": "doc_15_bed47bf2", "tag": "environment", "value": "beat"}
#   user.operation_name: {"doc_id": "doc_15_bed47bf2", "tag": "operation_name", "value": "help"}
#   user.mission_area: {"doc_id": "doc_15_bed47bf2", "tag": "mission_area", "value": "network"}
#   user.geo_scope: {"doc_id": "doc_15_bed47bf2", "tag": "geo_scope", "value": "both"}
#   user.cyber_domain: {"doc_id": "doc_15_bed47bf2", "tag": "cyber_domain", "value": "chance"}
#   user.policy_impact: {"doc_id": "doc_15_bed47bf2", "tag": "policy_impact", "value": "clear"}
#   user.audit_trail: {"doc_id": "doc_15_bed47bf2", "tag": "audit_trail", "value": "election"}
#
# file_name: doc_16_ca9e078b.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1241
# mod_time: Aug 26 15:34
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_16_ca9e078b", "tag": "classification", "value": "realize"}
#   user.classification_level: {"doc_id": "doc_16_ca9e078b", "tag": "classification_level", "value": "figure"}
#   user.originator_id: {"doc_id": "doc_16_ca9e078b", "tag": "originator_id", "value": "take"}
#   user.data_type: {"doc_id": "doc_16_ca9e078b", "tag": "data_type", "value": "vote"}
#   user.sensitivity: {"doc_id": "doc_16_ca9e078b", "tag": "sensitivity", "value": "kind"}
#   user.transfer_control: {"doc_id": "doc_16_ca9e078b", "tag": "transfer_control", "value": "size"}
#   user.data_owner: {"doc_id": "doc_16_ca9e078b", "tag": "data_owner", "value": "use"}
#   user.data_steward: {"doc_id": "doc_16_ca9e078b", "tag": "data_steward", "value": "population"}
#   user.dissemination_control: {"doc_id": "doc_16_ca9e078b", "tag": "dissemination_control", "value": "a"}
#   user.release_authority: {"doc_id": "doc_16_ca9e078b", "tag": "release_authority", "value": "live"}
#   user.document_type: {"doc_id": "doc_16_ca9e078b", "tag": "document_type", "value": "single"}
#   user.teaming_partner: {"doc_id": "doc_16_ca9e078b", "tag": "teaming_partner", "value": "live"}
#   user.handling_descriptor: {"doc_id": "doc_16_ca9e078b", "tag": "handling_descriptor", "value": "little"}
#   user.distribution_statement: {"doc_id": "doc_16_ca9e078b", "tag": "distribution_statement", "value": "century"}
#   user.sci_control: {"doc_id": "doc_16_ca9e078b", "tag": "sci_control", "value": "picture"}
#   user.caveats: {"doc_id": "doc_16_ca9e078b", "tag": "caveats", "value": "month"}
#   user.ps_percent_complete: {"doc_id": "doc_16_ca9e078b", "tag": "ps_percent_complete", "value": "offer"}
#   user.point_of_contact: {"doc_id": "doc_16_ca9e078b", "tag": "point_of_contact", "value": "room"}
#   user.report_version: {"doc_id": "doc_16_ca9e078b", "tag": "report_version", "value": "church"}
#   user.system_of_record: {"doc_id": "doc_16_ca9e078b", "tag": "system_of_record", "value": "way"}
#   user.citation: {"doc_id": "doc_16_ca9e078b", "tag": "citation", "value": "sport"}
#   user.related_doc: {"doc_id": "doc_16_ca9e078b", "tag": "related_doc", "value": "measure"}
#   user.platform: {"doc_id": "doc_16_ca9e078b", "tag": "platform", "value": "kind"}
#   user.environment: {"doc_id": "doc_16_ca9e078b", "tag": "environment", "value": "own"}
#   user.operation_name: {"doc_id": "doc_16_ca9e078b", "tag": "operation_name", "value": "plan"}
#   user.mission_area: {"doc_id": "doc_16_ca9e078b", "tag": "mission_area", "value": "make"}
#   user.geo_scope: {"doc_id": "doc_16_ca9e078b", "tag": "geo_scope", "value": "a"}
#   user.cyber_domain: {"doc_id": "doc_16_ca9e078b", "tag": "cyber_domain", "value": "although"}
#   user.policy_impact: {"doc_id": "doc_16_ca9e078b", "tag": "policy_impact", "value": "send"}
#   user.audit_trail: {"doc_id": "doc_16_ca9e078b", "tag": "audit_trail", "value": "behavior"}
#
# file_name: doc_17_6369f22a.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1224
# mod_time: Aug 26 15:34
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_17_6369f22a", "tag": "classification", "value": "night"}
#   user.classification_level: {"doc_id": "doc_17_6369f22a", "tag": "classification_level", "value": "eat"}
#   user.originator_id: {"doc_id": "doc_17_6369f22a", "tag": "originator_id", "value": "into"}
#   user.data_type: {"doc_id": "doc_17_6369f22a", "tag": "data_type", "value": "concern"}
#   user.sensitivity: {"doc_id": "doc_17_6369f22a", "tag": "sensitivity", "value": "sort"}
#   user.transfer_control: {"doc_id": "doc_17_6369f22a", "tag": "transfer_control", "value": "certain"}
#   user.data_owner: {"doc_id": "doc_17_6369f22a", "tag": "data_owner", "value": "hold"}
#   user.data_steward: {"doc_id": "doc_17_6369f22a", "tag": "data_steward", "value": "hotel"}
#   user.dissemination_control: {"doc_id": "doc_17_6369f22a", "tag": "dissemination_control", "value": "size"}
#   user.release_authority: {"doc_id": "doc_17_6369f22a", "tag": "release_authority", "value": "continue"}
#   user.document_type: {"doc_id": "doc_17_6369f22a", "tag": "document_type", "value": "anyone"}
#   user.teaming_partner: {"doc_id": "doc_17_6369f22a", "tag": "teaming_partner", "value": "large"}
#   user.handling_descriptor: {"doc_id": "doc_17_6369f22a", "tag": "handling_descriptor", "value": "early"}
#   user.distribution_statement: {"doc_id": "doc_17_6369f22a", "tag": "distribution_statement", "value": "rule"}
#   user.sci_control: {"doc_id": "doc_17_6369f22a", "tag": "sci_control", "value": "reduce"}
#   user.caveats: {"doc_id": "doc_17_6369f22a", "tag": "caveats", "value": "fund"}
#   user.ps_percent_complete: {"doc_id": "doc_17_6369f22a", "tag": "ps_percent_complete", "value": "color"}
#   user.point_of_contact: {"doc_id": "doc_17_6369f22a", "tag": "point_of_contact", "value": "rate"}
#   user.report_version: {"doc_id": "doc_17_6369f22a", "tag": "report_version", "value": "onto"}
#   user.system_of_record: {"doc_id": "doc_17_6369f22a", "tag": "system_of_record", "value": "factor"}
#   user.citation: {"doc_id": "doc_17_6369f22a", "tag": "citation", "value": "box"}
#   user.related_doc: {"doc_id": "doc_17_6369f22a", "tag": "related_doc", "value": "next"}
#   user.platform: {"doc_id": "doc_17_6369f22a", "tag": "platform", "value": "buy"}
#   user.environment: {"doc_id": "doc_17_6369f22a", "tag": "environment", "value": "miss"}
#   user.operation_name: {"doc_id": "doc_17_6369f22a", "tag": "operation_name", "value": "throw"}
#   user.mission_area: {"doc_id": "doc_17_6369f22a", "tag": "mission_area", "value": "shake"}
#   user.geo_scope: {"doc_id": "doc_17_6369f22a", "tag": "geo_scope", "value": "fact"}
#   user.cyber_domain: {"doc_id": "doc_17_6369f22a", "tag": "cyber_domain", "value": "someone"}
#   user.policy_impact: {"doc_id": "doc_17_6369f22a", "tag": "policy_impact", "value": "whom"}
#   user.audit_trail: {"doc_id": "doc_17_6369f22a", "tag": "audit_trail", "value": "north"}
#
# file_name: doc_18_be3862ca.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1334
# mod_time: Aug 26 15:34
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_18_be3862ca", "tag": "classification", "value": "hard"}
#   user.classification_level: {"doc_id": "doc_18_be3862ca", "tag": "classification_level", "value": "up"}
#   user.originator_id: {"doc_id": "doc_18_be3862ca", "tag": "originator_id", "value": "majority"}
#   user.data_type: {"doc_id": "doc_18_be3862ca", "tag": "data_type", "value": "somebody"}
#   user.sensitivity: {"doc_id": "doc_18_be3862ca", "tag": "sensitivity", "value": "strong"}
#   user.transfer_control: {"doc_id": "doc_18_be3862ca", "tag": "transfer_control", "value": "choose"}
#   user.data_owner: {"doc_id": "doc_18_be3862ca", "tag": "data_owner", "value": "station"}
#   user.data_steward: {"doc_id": "doc_18_be3862ca", "tag": "data_steward", "value": "difficult"}
#   user.dissemination_control: {"doc_id": "doc_18_be3862ca", "tag": "dissemination_control", "value": "reveal"}
#   user.release_authority: {"doc_id": "doc_18_be3862ca", "tag": "release_authority", "value": "star"}
#   user.document_type: {"doc_id": "doc_18_be3862ca", "tag": "document_type", "value": "participant"}
#   user.teaming_partner: {"doc_id": "doc_18_be3862ca", "tag": "teaming_partner", "value": "up"}
#   user.handling_descriptor: {"doc_id": "doc_18_be3862ca", "tag": "handling_descriptor", "value": "responsibility"}
#   user.distribution_statement: {"doc_id": "doc_18_be3862ca", "tag": "distribution_statement", "value": "woman"}
#   user.sci_control: {"doc_id": "doc_18_be3862ca", "tag": "sci_control", "value": "decision"}
#   user.caveats: {"doc_id": "doc_18_be3862ca", "tag": "caveats", "value": "participant"}
#   user.ps_percent_complete: {"doc_id": "doc_18_be3862ca", "tag": "ps_percent_complete", "value": "only"}
#   user.point_of_contact: {"doc_id": "doc_18_be3862ca", "tag": "point_of_contact", "value": "end"}
#   user.report_version: {"doc_id": "doc_18_be3862ca", "tag": "report_version", "value": "glass"}
#   user.system_of_record: {"doc_id": "doc_18_be3862ca", "tag": "system_of_record", "value": "morning"}
#   user.citation: {"doc_id": "doc_18_be3862ca", "tag": "citation", "value": "drive"}
#   user.related_doc: {"doc_id": "doc_18_be3862ca", "tag": "related_doc", "value": "late"}
#   user.platform: {"doc_id": "doc_18_be3862ca", "tag": "platform", "value": "near"}
#   user.environment: {"doc_id": "doc_18_be3862ca", "tag": "environment", "value": "play"}
#   user.operation_name: {"doc_id": "doc_18_be3862ca", "tag": "operation_name", "value": "identify"}
#   user.mission_area: {"doc_id": "doc_18_be3862ca", "tag": "mission_area", "value": "capital"}
#   user.geo_scope: {"doc_id": "doc_18_be3862ca", "tag": "geo_scope", "value": "concern"}
#   user.cyber_domain: {"doc_id": "doc_18_be3862ca", "tag": "cyber_domain", "value": "number"}
#   user.policy_impact: {"doc_id": "doc_18_be3862ca", "tag": "policy_impact", "value": "contain"}
#   user.audit_trail: {"doc_id": "doc_18_be3862ca", "tag": "audit_trail", "value": "help"}
#
# file_name: doc_19_d228dad8.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 93
# mod_time: Aug 26 15:34
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_19_d228dad8", "tag": "classification", "value": "chair"}
#   user.classification_level: {"doc_id": "doc_19_d228dad8", "tag": "classification_level", "value": "cut"}
#   user.originator_id: {"doc_id": "doc_19_d228dad8", "tag": "originator_id", "value": "result"}
#   user.data_type: {"doc_id": "doc_19_d228dad8", "tag": "data_type", "value": "top"}
#   user.sensitivity: {"doc_id": "doc_19_d228dad8", "tag": "sensitivity", "value": "mention"}
#   user.transfer_control: {"doc_id": "doc_19_d228dad8", "tag": "transfer_control", "value": "law"}
#   user.data_owner: {"doc_id": "doc_19_d228dad8", "tag": "data_owner", "value": "little"}
#   user.data_steward: {"doc_id": "doc_19_d228dad8", "tag": "data_steward", "value": "democratic"}
#   user.dissemination_control: {"doc_id": "doc_19_d228dad8", "tag": "dissemination_control", "value": "feel"}
#   user.release_authority: {"doc_id": "doc_19_d228dad8", "tag": "release_authority", "value": "community"}
#   user.document_type: {"doc_id": "doc_19_d228dad8", "tag": "document_type", "value": "president"}
#   user.teaming_partner: {"doc_id": "doc_19_d228dad8", "tag": "teaming_partner", "value": "kitchen"}
#   user.handling_descriptor: {"doc_id": "doc_19_d228dad8", "tag": "handling_descriptor", "value": "lose"}
#   user.distribution_statement: {"doc_id": "doc_19_d228dad8", "tag": "distribution_statement", "value": "ten"}
#   user.sci_control: {"doc_id": "doc_19_d228dad8", "tag": "sci_control", "value": "mouth"}
#   user.caveats: {"doc_id": "doc_19_d228dad8", "tag": "caveats", "value": "cover"}
#   user.ps_percent_complete: {"doc_id": "doc_19_d228dad8", "tag": "ps_percent_complete", "value": "after"}
#   user.point_of_contact: {"doc_id": "doc_19_d228dad8", "tag": "point_of_contact", "value": "house"}
#   user.report_version: {"doc_id": "doc_19_d228dad8", "tag": "report_version", "value": "keep"}
#   user.system_of_record: {"doc_id": "doc_19_d228dad8", "tag": "system_of_record", "value": "city"}
#   user.citation: {"doc_id": "doc_19_d228dad8", "tag": "citation", "value": "issue"}
#   user.related_doc: {"doc_id": "doc_19_d228dad8", "tag": "related_doc", "value": "resource"}
#   user.platform: {"doc_id": "doc_19_d228dad8", "tag": "platform", "value": "everything"}
#   user.environment: {"doc_id": "doc_19_d228dad8", "tag": "environment", "value": "indicate"}
#   user.operation_name: {"doc_id": "doc_19_d228dad8", "tag": "operation_name", "value": "live"}
#   user.mission_area: {"doc_id": "doc_19_d228dad8", "tag": "mission_area", "value": "while"}
#   user.geo_scope: {"doc_id": "doc_19_d228dad8", "tag": "geo_scope", "value": "during"}
#   user.cyber_domain: {"doc_id": "doc_19_d228dad8", "tag": "cyber_domain", "value": "think"}
#   user.policy_impact: {"doc_id": "doc_19_d228dad8", "tag": "policy_impact", "value": "number"}
#   user.audit_trail: {"doc_id": "doc_19_d228dad8", "tag": "audit_trail", "value": "growth"}
#
# file_name: doc_1_07a093e8.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1416
# mod_time: Aug 26 15:31
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_1_07a093e8", "tag": "classification", "value": "their"}
#   user.classification_level: {"doc_id": "doc_1_07a093e8", "tag": "classification_level", "value": "value"}
#   user.originator_id: {"doc_id": "doc_1_07a093e8", "tag": "originator_id", "value": "need"}
#   user.data_type: {"doc_id": "doc_1_07a093e8", "tag": "data_type", "value": "instead"}
#   user.sensitivity: {"doc_id": "doc_1_07a093e8", "tag": "sensitivity", "value": "for"}
#   user.transfer_control: {"doc_id": "doc_1_07a093e8", "tag": "transfer_control", "value": "decade"}
#   user.data_owner: {"doc_id": "doc_1_07a093e8", "tag": "data_owner", "value": "green"}
#   user.data_steward: {"doc_id": "doc_1_07a093e8", "tag": "data_steward", "value": "minute"}
#   user.dissemination_control: {"doc_id": "doc_1_07a093e8", "tag": "dissemination_control", "value": "standard"}
#   user.release_authority: {"doc_id": "doc_1_07a093e8", "tag": "release_authority", "value": "opportunity"}
#   user.document_type: {"doc_id": "doc_1_07a093e8", "tag": "document_type", "value": "care"}
#   user.teaming_partner: {"doc_id": "doc_1_07a093e8", "tag": "teaming_partner", "value": "occur"}
#   user.handling_descriptor: {"doc_id": "doc_1_07a093e8", "tag": "handling_descriptor", "value": "voice"}
#   user.distribution_statement: {"doc_id": "doc_1_07a093e8", "tag": "distribution_statement", "value": "back"}
#   user.sci_control: {"doc_id": "doc_1_07a093e8", "tag": "sci_control", "value": "not"}
#   user.caveats: {"doc_id": "doc_1_07a093e8", "tag": "caveats", "value": "sometimes"}
#   user.ps_percent_complete: {"doc_id": "doc_1_07a093e8", "tag": "ps_percent_complete", "value": "middle"}
#   user.point_of_contact: {"doc_id": "doc_1_07a093e8", "tag": "point_of_contact", "value": "Republican"}
#   user.report_version: {"doc_id": "doc_1_07a093e8", "tag": "report_version", "value": "instead"}
#   user.system_of_record: {"doc_id": "doc_1_07a093e8", "tag": "system_of_record", "value": "term"}
#   user.citation: {"doc_id": "doc_1_07a093e8", "tag": "citation", "value": "do"}
#   user.related_doc: {"doc_id": "doc_1_07a093e8", "tag": "related_doc", "value": "black"}
#   user.platform: {"doc_id": "doc_1_07a093e8", "tag": "platform", "value": "effect"}
#   user.environment: {"doc_id": "doc_1_07a093e8", "tag": "environment", "value": "music"}
#   user.operation_name: {"doc_id": "doc_1_07a093e8", "tag": "operation_name", "value": "education"}
#   user.mission_area: {"doc_id": "doc_1_07a093e8", "tag": "mission_area", "value": "Mr"}
#   user.geo_scope: {"doc_id": "doc_1_07a093e8", "tag": "geo_scope", "value": "time"}
#   user.cyber_domain: {"doc_id": "doc_1_07a093e8", "tag": "cyber_domain", "value": "paper"}
#   user.policy_impact: {"doc_id": "doc_1_07a093e8", "tag": "policy_impact", "value": "agreement"}
#   user.audit_trail: {"doc_id": "doc_1_07a093e8", "tag": "audit_trail", "value": "benefit"}
#
# file_name: doc_20_5e0a265f.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1422
# mod_time: Aug 26 15:34
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_20_5e0a265f", "tag": "classification", "value": "guy"}
#   user.classification_level: {"doc_id": "doc_20_5e0a265f", "tag": "classification_level", "value": "heavy"}
#   user.originator_id: {"doc_id": "doc_20_5e0a265f", "tag": "originator_id", "value": "difficult"}
#   user.data_type: {"doc_id": "doc_20_5e0a265f", "tag": "data_type", "value": "within"}
#   user.sensitivity: {"doc_id": "doc_20_5e0a265f", "tag": "sensitivity", "value": "billion"}
#   user.transfer_control: {"doc_id": "doc_20_5e0a265f", "tag": "transfer_control", "value": "age"}
#   user.data_owner: {"doc_id": "doc_20_5e0a265f", "tag": "data_owner", "value": "others"}
#   user.data_steward: {"doc_id": "doc_20_5e0a265f", "tag": "data_steward", "value": "citizen"}
#   user.dissemination_control: {"doc_id": "doc_20_5e0a265f", "tag": "dissemination_control", "value": "beat"}
#   user.release_authority: {"doc_id": "doc_20_5e0a265f", "tag": "release_authority", "value": "energy"}
#   user.document_type: {"doc_id": "doc_20_5e0a265f", "tag": "document_type", "value": "everyone"}
#   user.teaming_partner: {"doc_id": "doc_20_5e0a265f", "tag": "teaming_partner", "value": "wife"}
#   user.handling_descriptor: {"doc_id": "doc_20_5e0a265f", "tag": "handling_descriptor", "value": "no"}
#   user.distribution_statement: {"doc_id": "doc_20_5e0a265f", "tag": "distribution_statement", "value": "right"}
#   user.sci_control: {"doc_id": "doc_20_5e0a265f", "tag": "sci_control", "value": "law"}
#   user.caveats: {"doc_id": "doc_20_5e0a265f", "tag": "caveats", "value": "American"}
#   user.ps_percent_complete: {"doc_id": "doc_20_5e0a265f", "tag": "ps_percent_complete", "value": "grow"}
#   user.point_of_contact: {"doc_id": "doc_20_5e0a265f", "tag": "point_of_contact", "value": "parent"}
#   user.report_version: {"doc_id": "doc_20_5e0a265f", "tag": "report_version", "value": "study"}
#   user.system_of_record: {"doc_id": "doc_20_5e0a265f", "tag": "system_of_record", "value": "firm"}
#   user.citation: {"doc_id": "doc_20_5e0a265f", "tag": "citation", "value": "work"}
#   user.related_doc: {"doc_id": "doc_20_5e0a265f", "tag": "related_doc", "value": "reach"}
#   user.platform: {"doc_id": "doc_20_5e0a265f", "tag": "platform", "value": "force"}
#   user.environment: {"doc_id": "doc_20_5e0a265f", "tag": "environment", "value": "share"}
#   user.operation_name: {"doc_id": "doc_20_5e0a265f", "tag": "operation_name", "value": "cultural"}
#   user.mission_area: {"doc_id": "doc_20_5e0a265f", "tag": "mission_area", "value": "establish"}
#   user.geo_scope: {"doc_id": "doc_20_5e0a265f", "tag": "geo_scope", "value": "treatment"}
#   user.cyber_domain: {"doc_id": "doc_20_5e0a265f", "tag": "cyber_domain", "value": "tough"}
#   user.policy_impact: {"doc_id": "doc_20_5e0a265f", "tag": "policy_impact", "value": "public"}
#   user.audit_trail: {"doc_id": "doc_20_5e0a265f", "tag": "audit_trail", "value": "some"}
#
# file_name: doc_21_25f255b3.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 113
# mod_time: Aug 26 15:34
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_21_25f255b3", "tag": "classification", "value": "task"}
#   user.classification_level: {"doc_id": "doc_21_25f255b3", "tag": "classification_level", "value": "operation"}
#   user.originator_id: {"doc_id": "doc_21_25f255b3", "tag": "originator_id", "value": "wide"}
#   user.data_type: {"doc_id": "doc_21_25f255b3", "tag": "data_type", "value": "garden"}
#   user.sensitivity: {"doc_id": "doc_21_25f255b3", "tag": "sensitivity", "value": "do"}
#   user.transfer_control: {"doc_id": "doc_21_25f255b3", "tag": "transfer_control", "value": "allow"}
#   user.data_owner: {"doc_id": "doc_21_25f255b3", "tag": "data_owner", "value": "name"}
#   user.data_steward: {"doc_id": "doc_21_25f255b3", "tag": "data_steward", "value": "newspaper"}
#   user.dissemination_control: {"doc_id": "doc_21_25f255b3", "tag": "dissemination_control", "value": "also"}
#   user.release_authority: {"doc_id": "doc_21_25f255b3", "tag": "release_authority", "value": "chance"}
#   user.document_type: {"doc_id": "doc_21_25f255b3", "tag": "document_type", "value": "raise"}
#   user.teaming_partner: {"doc_id": "doc_21_25f255b3", "tag": "teaming_partner", "value": "color"}
#   user.handling_descriptor: {"doc_id": "doc_21_25f255b3", "tag": "handling_descriptor", "value": "space"}
#   user.distribution_statement: {"doc_id": "doc_21_25f255b3", "tag": "distribution_statement", "value": "me"}
#   user.sci_control: {"doc_id": "doc_21_25f255b3", "tag": "sci_control", "value": "lay"}
#   user.caveats: {"doc_id": "doc_21_25f255b3", "tag": "caveats", "value": "foreign"}
#   user.ps_percent_complete: {"doc_id": "doc_21_25f255b3", "tag": "ps_percent_complete", "value": "magazine"}
#   user.point_of_contact: {"doc_id": "doc_21_25f255b3", "tag": "point_of_contact", "value": "east"}
#   user.report_version: {"doc_id": "doc_21_25f255b3", "tag": "report_version", "value": "issue"}
#   user.system_of_record: {"doc_id": "doc_21_25f255b3", "tag": "system_of_record", "value": "every"}
#   user.citation: {"doc_id": "doc_21_25f255b3", "tag": "citation", "value": "yes"}
#   user.related_doc: {"doc_id": "doc_21_25f255b3", "tag": "related_doc", "value": "put"}
#   user.platform: {"doc_id": "doc_21_25f255b3", "tag": "platform", "value": "treatment"}
#   user.environment: {"doc_id": "doc_21_25f255b3", "tag": "environment", "value": "read"}
#   user.operation_name: {"doc_id": "doc_21_25f255b3", "tag": "operation_name", "value": "often"}
#   user.mission_area: {"doc_id": "doc_21_25f255b3", "tag": "mission_area", "value": "trip"}
#   user.geo_scope: {"doc_id": "doc_21_25f255b3", "tag": "geo_scope", "value": "white"}
#   user.cyber_domain: {"doc_id": "doc_21_25f255b3", "tag": "cyber_domain", "value": "social"}
#   user.policy_impact: {"doc_id": "doc_21_25f255b3", "tag": "policy_impact", "value": "agreement"}
#   user.audit_trail: {"doc_id": "doc_21_25f255b3", "tag": "audit_trail", "value": "wife"}
#
# file_name: doc_22_09ca34a0.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1224
# mod_time: Aug 26 15:34
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_22_09ca34a0", "tag": "classification", "value": "source"}
#   user.classification_level: {"doc_id": "doc_22_09ca34a0", "tag": "classification_level", "value": "discussion"}
#   user.originator_id: {"doc_id": "doc_22_09ca34a0", "tag": "originator_id", "value": "view"}
#   user.data_type: {"doc_id": "doc_22_09ca34a0", "tag": "data_type", "value": "throw"}
#   user.sensitivity: {"doc_id": "doc_22_09ca34a0", "tag": "sensitivity", "value": "kind"}
#   user.transfer_control: {"doc_id": "doc_22_09ca34a0", "tag": "transfer_control", "value": "money"}
#   user.data_owner: {"doc_id": "doc_22_09ca34a0", "tag": "data_owner", "value": "college"}
#   user.data_steward: {"doc_id": "doc_22_09ca34a0", "tag": "data_steward", "value": "realize"}
#   user.dissemination_control: {"doc_id": "doc_22_09ca34a0", "tag": "dissemination_control", "value": "drive"}
#   user.release_authority: {"doc_id": "doc_22_09ca34a0", "tag": "release_authority", "value": "remain"}
#   user.document_type: {"doc_id": "doc_22_09ca34a0", "tag": "document_type", "value": "notice"}
#   user.teaming_partner: {"doc_id": "doc_22_09ca34a0", "tag": "teaming_partner", "value": "go"}
#   user.handling_descriptor: {"doc_id": "doc_22_09ca34a0", "tag": "handling_descriptor", "value": "more"}
#   user.distribution_statement: {"doc_id": "doc_22_09ca34a0", "tag": "distribution_statement", "value": "sport"}
#   user.sci_control: {"doc_id": "doc_22_09ca34a0", "tag": "sci_control", "value": "discover"}
#   user.caveats: {"doc_id": "doc_22_09ca34a0", "tag": "caveats", "value": "professor"}
#   user.ps_percent_complete: {"doc_id": "doc_22_09ca34a0", "tag": "ps_percent_complete", "value": "soon"}
#   user.point_of_contact: {"doc_id": "doc_22_09ca34a0", "tag": "point_of_contact", "value": "sing"}
#   user.report_version: {"doc_id": "doc_22_09ca34a0", "tag": "report_version", "value": "past"}
#   user.system_of_record: {"doc_id": "doc_22_09ca34a0", "tag": "system_of_record", "value": "especially"}
#   user.citation: {"doc_id": "doc_22_09ca34a0", "tag": "citation", "value": "agent"}
#   user.related_doc: {"doc_id": "doc_22_09ca34a0", "tag": "related_doc", "value": "each"}
#   user.platform: {"doc_id": "doc_22_09ca34a0", "tag": "platform", "value": "morning"}
#   user.environment: {"doc_id": "doc_22_09ca34a0", "tag": "environment", "value": "of"}
#   user.operation_name: {"doc_id": "doc_22_09ca34a0", "tag": "operation_name", "value": "job"}
#   user.mission_area: {"doc_id": "doc_22_09ca34a0", "tag": "mission_area", "value": "skill"}
#   user.geo_scope: {"doc_id": "doc_22_09ca34a0", "tag": "geo_scope", "value": "industry"}
#   user.cyber_domain: {"doc_id": "doc_22_09ca34a0", "tag": "cyber_domain", "value": "up"}
#   user.policy_impact: {"doc_id": "doc_22_09ca34a0", "tag": "policy_impact", "value": "address"}
#   user.audit_trail: {"doc_id": "doc_22_09ca34a0", "tag": "audit_trail", "value": "future"}
#
# file_name: doc_23_cd92b448.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1482
# mod_time: Aug 26 15:34
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_23_cd92b448", "tag": "classification", "value": "themselves"}
#   user.classification_level: {"doc_id": "doc_23_cd92b448", "tag": "classification_level", "value": "well"}
#   user.originator_id: {"doc_id": "doc_23_cd92b448", "tag": "originator_id", "value": "nature"}
#   user.data_type: {"doc_id": "doc_23_cd92b448", "tag": "data_type", "value": "chair"}
#   user.sensitivity: {"doc_id": "doc_23_cd92b448", "tag": "sensitivity", "value": "week"}
#   user.transfer_control: {"doc_id": "doc_23_cd92b448", "tag": "transfer_control", "value": "major"}
#   user.data_owner: {"doc_id": "doc_23_cd92b448", "tag": "data_owner", "value": "pull"}
#   user.data_steward: {"doc_id": "doc_23_cd92b448", "tag": "data_steward", "value": "show"}
#   user.dissemination_control: {"doc_id": "doc_23_cd92b448", "tag": "dissemination_control", "value": "hot"}
#   user.release_authority: {"doc_id": "doc_23_cd92b448", "tag": "release_authority", "value": "get"}
#   user.document_type: {"doc_id": "doc_23_cd92b448", "tag": "document_type", "value": "father"}
#   user.teaming_partner: {"doc_id": "doc_23_cd92b448", "tag": "teaming_partner", "value": "than"}
#   user.handling_descriptor: {"doc_id": "doc_23_cd92b448", "tag": "handling_descriptor", "value": "central"}
#   user.distribution_statement: {"doc_id": "doc_23_cd92b448", "tag": "distribution_statement", "value": "notice"}
#   user.sci_control: {"doc_id": "doc_23_cd92b448", "tag": "sci_control", "value": "hit"}
#   user.caveats: {"doc_id": "doc_23_cd92b448", "tag": "caveats", "value": "through"}
#   user.ps_percent_complete: {"doc_id": "doc_23_cd92b448", "tag": "ps_percent_complete", "value": "body"}
#   user.point_of_contact: {"doc_id": "doc_23_cd92b448", "tag": "point_of_contact", "value": "couple"}
#   user.report_version: {"doc_id": "doc_23_cd92b448", "tag": "report_version", "value": "whether"}
#   user.system_of_record: {"doc_id": "doc_23_cd92b448", "tag": "system_of_record", "value": "may"}
#   user.citation: {"doc_id": "doc_23_cd92b448", "tag": "citation", "value": "allow"}
#   user.related_doc: {"doc_id": "doc_23_cd92b448", "tag": "related_doc", "value": "position"}
#   user.platform: {"doc_id": "doc_23_cd92b448", "tag": "platform", "value": "model"}
#   user.environment: {"doc_id": "doc_23_cd92b448", "tag": "environment", "value": "poor"}
#   user.operation_name: {"doc_id": "doc_23_cd92b448", "tag": "operation_name", "value": "population"}
#   user.mission_area: {"doc_id": "doc_23_cd92b448", "tag": "mission_area", "value": "view"}
#   user.geo_scope: {"doc_id": "doc_23_cd92b448", "tag": "geo_scope", "value": "late"}
# ...
#   user.citation: {"doc_id": "doc_4_f57aa897", "tag": "citation", "value": "peace"}
#   user.related_doc: {"doc_id": "doc_4_f57aa897", "tag": "related_doc", "value": "job"}
#   user.platform: {"doc_id": "doc_4_f57aa897", "tag": "platform", "value": "hour"}
#   user.environment: {"doc_id": "doc_4_f57aa897", "tag": "environment", "value": "respond"}
#   user.operation_name: {"doc_id": "doc_4_f57aa897", "tag": "operation_name", "value": "say"}
#   user.mission_area: {"doc_id": "doc_4_f57aa897", "tag": "mission_area", "value": "wonder"}
#   user.geo_scope: {"doc_id": "doc_4_f57aa897", "tag": "geo_scope", "value": "team"}
#   user.cyber_domain: {"doc_id": "doc_4_f57aa897", "tag": "cyber_domain", "value": "chance"}
#   user.policy_impact: {"doc_id": "doc_4_f57aa897", "tag": "policy_impact", "value": "forget"}
#   user.audit_trail: {"doc_id": "doc_4_f57aa897", "tag": "audit_trail", "value": "thing"}
#
# file_name: doc_5_8ef086e7.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1402
# mod_time: Aug 26 15:32
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_5_8ef086e7", "tag": "classification", "value": "together"}
#   user.classification_level: {"doc_id": "doc_5_8ef086e7", "tag": "classification_level", "value": "trial"}
#   user.originator_id: {"doc_id": "doc_5_8ef086e7", "tag": "originator_id", "value": "PM"}
#   user.data_type: {"doc_id": "doc_5_8ef086e7", "tag": "data_type", "value": "music"}
#   user.sensitivity: {"doc_id": "doc_5_8ef086e7", "tag": "sensitivity", "value": "professor"}
#   user.transfer_control: {"doc_id": "doc_5_8ef086e7", "tag": "transfer_control", "value": "bed"}
#   user.data_owner: {"doc_id": "doc_5_8ef086e7", "tag": "data_owner", "value": "toward"}
#   user.data_steward: {"doc_id": "doc_5_8ef086e7", "tag": "data_steward", "value": "ask"}
#   user.dissemination_control: {"doc_id": "doc_5_8ef086e7", "tag": "dissemination_control", "value": "pass"}
#   user.release_authority: {"doc_id": "doc_5_8ef086e7", "tag": "release_authority", "value": "herself"}
#   user.document_type: {"doc_id": "doc_5_8ef086e7", "tag": "document_type", "value": "half"}
#   user.teaming_partner: {"doc_id": "doc_5_8ef086e7", "tag": "teaming_partner", "value": "score"}
#   user.handling_descriptor: {"doc_id": "doc_5_8ef086e7", "tag": "handling_descriptor", "value": "claim"}
#   user.distribution_statement: {"doc_id": "doc_5_8ef086e7", "tag": "distribution_statement", "value": "technology"}
#   user.sci_control: {"doc_id": "doc_5_8ef086e7", "tag": "sci_control", "value": "choice"}
#   user.caveats: {"doc_id": "doc_5_8ef086e7", "tag": "caveats", "value": "message"}
#   user.ps_percent_complete: {"doc_id": "doc_5_8ef086e7", "tag": "ps_percent_complete", "value": "threat"}
#   user.point_of_contact: {"doc_id": "doc_5_8ef086e7", "tag": "point_of_contact", "value": "trip"}
#   user.report_version: {"doc_id": "doc_5_8ef086e7", "tag": "report_version", "value": "in"}
#   user.system_of_record: {"doc_id": "doc_5_8ef086e7", "tag": "system_of_record", "value": "when"}
#   user.citation: {"doc_id": "doc_5_8ef086e7", "tag": "citation", "value": "continue"}
#   user.related_doc: {"doc_id": "doc_5_8ef086e7", "tag": "related_doc", "value": "business"}
#   user.platform: {"doc_id": "doc_5_8ef086e7", "tag": "platform", "value": "sound"}
#   user.environment: {"doc_id": "doc_5_8ef086e7", "tag": "environment", "value": "speak"}
#   user.operation_name: {"doc_id": "doc_5_8ef086e7", "tag": "operation_name", "value": "especially"}
#   user.mission_area: {"doc_id": "doc_5_8ef086e7", "tag": "mission_area", "value": "enough"}
#   user.geo_scope: {"doc_id": "doc_5_8ef086e7", "tag": "geo_scope", "value": "many"}
#   user.cyber_domain: {"doc_id": "doc_5_8ef086e7", "tag": "cyber_domain", "value": "green"}
#   user.policy_impact: {"doc_id": "doc_5_8ef086e7", "tag": "policy_impact", "value": "blue"}
#   user.audit_trail: {"doc_id": "doc_5_8ef086e7", "tag": "audit_trail", "value": "newspaper"}
#
# file_name: doc_6_362e87b1.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1311
# mod_time: Aug 26 15:32
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_6_362e87b1", "tag": "classification", "value": "place"}
#   user.classification_level: {"doc_id": "doc_6_362e87b1", "tag": "classification_level", "value": "prepare"}
#   user.originator_id: {"doc_id": "doc_6_362e87b1", "tag": "originator_id", "value": "west"}
#   user.data_type: {"doc_id": "doc_6_362e87b1", "tag": "data_type", "value": "little"}
#   user.sensitivity: {"doc_id": "doc_6_362e87b1", "tag": "sensitivity", "value": "card"}
#   user.transfer_control: {"doc_id": "doc_6_362e87b1", "tag": "transfer_control", "value": "responsibility"}
#   user.data_owner: {"doc_id": "doc_6_362e87b1", "tag": "data_owner", "value": "community"}
#   user.data_steward: {"doc_id": "doc_6_362e87b1", "tag": "data_steward", "value": "community"}
#   user.dissemination_control: {"doc_id": "doc_6_362e87b1", "tag": "dissemination_control", "value": "strong"}
#   user.release_authority: {"doc_id": "doc_6_362e87b1", "tag": "release_authority", "value": "business"}
#   user.document_type: {"doc_id": "doc_6_362e87b1", "tag": "document_type", "value": "others"}
#   user.teaming_partner: {"doc_id": "doc_6_362e87b1", "tag": "teaming_partner", "value": "page"}
#   user.handling_descriptor: {"doc_id": "doc_6_362e87b1", "tag": "handling_descriptor", "value": "carry"}
#   user.distribution_statement: {"doc_id": "doc_6_362e87b1", "tag": "distribution_statement", "value": "field"}
#   user.sci_control: {"doc_id": "doc_6_362e87b1", "tag": "sci_control", "value": "southern"}
#   user.caveats: {"doc_id": "doc_6_362e87b1", "tag": "caveats", "value": "several"}
#   user.ps_percent_complete: {"doc_id": "doc_6_362e87b1", "tag": "ps_percent_complete", "value": "know"}
#   user.point_of_contact: {"doc_id": "doc_6_362e87b1", "tag": "point_of_contact", "value": "exist"}
#   user.report_version: {"doc_id": "doc_6_362e87b1", "tag": "report_version", "value": "forget"}
#   user.system_of_record: {"doc_id": "doc_6_362e87b1", "tag": "system_of_record", "value": "his"}
#   user.citation: {"doc_id": "doc_6_362e87b1", "tag": "citation", "value": "out"}
#   user.related_doc: {"doc_id": "doc_6_362e87b1", "tag": "related_doc", "value": "onto"}
#   user.platform: {"doc_id": "doc_6_362e87b1", "tag": "platform", "value": "seem"}
#   user.environment: {"doc_id": "doc_6_362e87b1", "tag": "environment", "value": "article"}
#   user.operation_name: {"doc_id": "doc_6_362e87b1", "tag": "operation_name", "value": "several"}
#   user.mission_area: {"doc_id": "doc_6_362e87b1", "tag": "mission_area", "value": "fall"}
#   user.geo_scope: {"doc_id": "doc_6_362e87b1", "tag": "geo_scope", "value": "car"}
#   user.cyber_domain: {"doc_id": "doc_6_362e87b1", "tag": "cyber_domain", "value": "under"}
#   user.policy_impact: {"doc_id": "doc_6_362e87b1", "tag": "policy_impact", "value": "line"}
#   user.audit_trail: {"doc_id": "doc_6_362e87b1", "tag": "audit_trail", "value": "theory"}
#
# file_name: doc_7_c5d8d58b.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1301
# mod_time: Aug 26 15:32
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_7_c5d8d58b", "tag": "classification", "value": "magazine"}
#   user.classification_level: {"doc_id": "doc_7_c5d8d58b", "tag": "classification_level", "value": "economic"}
#   user.originator_id: {"doc_id": "doc_7_c5d8d58b", "tag": "originator_id", "value": "sea"}
#   user.data_type: {"doc_id": "doc_7_c5d8d58b", "tag": "data_type", "value": "floor"}
#   user.sensitivity: {"doc_id": "doc_7_c5d8d58b", "tag": "sensitivity", "value": "picture"}
#   user.transfer_control: {"doc_id": "doc_7_c5d8d58b", "tag": "transfer_control", "value": "wear"}
#   user.data_owner: {"doc_id": "doc_7_c5d8d58b", "tag": "data_owner", "value": "sing"}
#   user.data_steward: {"doc_id": "doc_7_c5d8d58b", "tag": "data_steward", "value": "order"}
#   user.dissemination_control: {"doc_id": "doc_7_c5d8d58b", "tag": "dissemination_control", "value": "still"}
#   user.release_authority: {"doc_id": "doc_7_c5d8d58b", "tag": "release_authority", "value": "store"}
#   user.document_type: {"doc_id": "doc_7_c5d8d58b", "tag": "document_type", "value": "plant"}
#   user.teaming_partner: {"doc_id": "doc_7_c5d8d58b", "tag": "teaming_partner", "value": "concern"}
#   user.handling_descriptor: {"doc_id": "doc_7_c5d8d58b", "tag": "handling_descriptor", "value": "body"}
#   user.distribution_statement: {"doc_id": "doc_7_c5d8d58b", "tag": "distribution_statement", "value": "add"}
#   user.sci_control: {"doc_id": "doc_7_c5d8d58b", "tag": "sci_control", "value": "return"}
#   user.caveats: {"doc_id": "doc_7_c5d8d58b", "tag": "caveats", "value": "sound"}
#   user.ps_percent_complete: {"doc_id": "doc_7_c5d8d58b", "tag": "ps_percent_complete", "value": "black"}
#   user.point_of_contact: {"doc_id": "doc_7_c5d8d58b", "tag": "point_of_contact", "value": "herself"}
#   user.report_version: {"doc_id": "doc_7_c5d8d58b", "tag": "report_version", "value": "when"}
#   user.system_of_record: {"doc_id": "doc_7_c5d8d58b", "tag": "system_of_record", "value": "less"}
#   user.citation: {"doc_id": "doc_7_c5d8d58b", "tag": "citation", "value": "up"}
#   user.related_doc: {"doc_id": "doc_7_c5d8d58b", "tag": "related_doc", "value": "side"}
#   user.platform: {"doc_id": "doc_7_c5d8d58b", "tag": "platform", "value": "look"}
#   user.environment: {"doc_id": "doc_7_c5d8d58b", "tag": "environment", "value": "inside"}
#   user.operation_name: {"doc_id": "doc_7_c5d8d58b", "tag": "operation_name", "value": "good"}
#   user.mission_area: {"doc_id": "doc_7_c5d8d58b", "tag": "mission_area", "value": "deal"}
#   user.geo_scope: {"doc_id": "doc_7_c5d8d58b", "tag": "geo_scope", "value": "day"}
#   user.cyber_domain: {"doc_id": "doc_7_c5d8d58b", "tag": "cyber_domain", "value": "attention"}
#   user.policy_impact: {"doc_id": "doc_7_c5d8d58b", "tag": "policy_impact", "value": "look"}
#   user.audit_trail: {"doc_id": "doc_7_c5d8d58b", "tag": "audit_trail", "value": "many"}
#
# file_name: doc_8_858492dd.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1432
# mod_time: Aug 26 15:32
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_8_858492dd", "tag": "classification", "value": "pressure"}
#   user.classification_level: {"doc_id": "doc_8_858492dd", "tag": "classification_level", "value": "wide"}
#   user.originator_id: {"doc_id": "doc_8_858492dd", "tag": "originator_id", "value": "door"}
#   user.data_type: {"doc_id": "doc_8_858492dd", "tag": "data_type", "value": "war"}
#   user.sensitivity: {"doc_id": "doc_8_858492dd", "tag": "sensitivity", "value": "card"}
#   user.transfer_control: {"doc_id": "doc_8_858492dd", "tag": "transfer_control", "value": "water"}
#   user.data_owner: {"doc_id": "doc_8_858492dd", "tag": "data_owner", "value": "democratic"}
#   user.data_steward: {"doc_id": "doc_8_858492dd", "tag": "data_steward", "value": "like"}
#   user.dissemination_control: {"doc_id": "doc_8_858492dd", "tag": "dissemination_control", "value": "top"}
#   user.release_authority: {"doc_id": "doc_8_858492dd", "tag": "release_authority", "value": "interesting"}
#   user.document_type: {"doc_id": "doc_8_858492dd", "tag": "document_type", "value": "woman"}
#   user.teaming_partner: {"doc_id": "doc_8_858492dd", "tag": "teaming_partner", "value": "physical"}
#   user.handling_descriptor: {"doc_id": "doc_8_858492dd", "tag": "handling_descriptor", "value": "prepare"}
#   user.distribution_statement: {"doc_id": "doc_8_858492dd", "tag": "distribution_statement", "value": "two"}
#   user.sci_control: {"doc_id": "doc_8_858492dd", "tag": "sci_control", "value": "hand"}
#   user.caveats: {"doc_id": "doc_8_858492dd", "tag": "caveats", "value": "lawyer"}
#   user.ps_percent_complete: {"doc_id": "doc_8_858492dd", "tag": "ps_percent_complete", "value": "its"}
#   user.point_of_contact: {"doc_id": "doc_8_858492dd", "tag": "point_of_contact", "value": "fast"}
#   user.report_version: {"doc_id": "doc_8_858492dd", "tag": "report_version", "value": "foreign"}
#   user.system_of_record: {"doc_id": "doc_8_858492dd", "tag": "system_of_record", "value": "road"}
#   user.citation: {"doc_id": "doc_8_858492dd", "tag": "citation", "value": "employee"}
#   user.related_doc: {"doc_id": "doc_8_858492dd", "tag": "related_doc", "value": "theory"}
#   user.platform: {"doc_id": "doc_8_858492dd", "tag": "platform", "value": "southern"}
#   user.environment: {"doc_id": "doc_8_858492dd", "tag": "environment", "value": "ask"}
#   user.operation_name: {"doc_id": "doc_8_858492dd", "tag": "operation_name", "value": "bag"}
#   user.mission_area: {"doc_id": "doc_8_858492dd", "tag": "mission_area", "value": "wide"}
#   user.geo_scope: {"doc_id": "doc_8_858492dd", "tag": "geo_scope", "value": "than"}
#   user.cyber_domain: {"doc_id": "doc_8_858492dd", "tag": "cyber_domain", "value": "could"}
#   user.policy_impact: {"doc_id": "doc_8_858492dd", "tag": "policy_impact", "value": "onto"}
#   user.audit_trail: {"doc_id": "doc_8_858492dd", "tag": "audit_trail", "value": "same"}
#
# file_name: doc_9_d5cc8dfc.txt
# block_size: 4096
# permission: 664
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 1364
# mod_time: Aug 26 15:32
# plus xattr metadata:
#   user.classification: {"doc_id": "doc_9_d5cc8dfc", "tag": "classification", "value": "building"}
#   user.classification_level: {"doc_id": "doc_9_d5cc8dfc", "tag": "classification_level", "value": "not"}
#   user.originator_id: {"doc_id": "doc_9_d5cc8dfc", "tag": "originator_id", "value": "trade"}
#   user.data_type: {"doc_id": "doc_9_d5cc8dfc", "tag": "data_type", "value": "rise"}
#   user.sensitivity: {"doc_id": "doc_9_d5cc8dfc", "tag": "sensitivity", "value": "lay"}
#   user.transfer_control: {"doc_id": "doc_9_d5cc8dfc", "tag": "transfer_control", "value": "no"}
#   user.data_owner: {"doc_id": "doc_9_d5cc8dfc", "tag": "data_owner", "value": "five"}
#   user.data_steward: {"doc_id": "doc_9_d5cc8dfc", "tag": "data_steward", "value": "position"}
#   user.dissemination_control: {"doc_id": "doc_9_d5cc8dfc", "tag": "dissemination_control", "value": "player"}
#   user.release_authority: {"doc_id": "doc_9_d5cc8dfc", "tag": "release_authority", "value": "anything"}
#   user.document_type: {"doc_id": "doc_9_d5cc8dfc", "tag": "document_type", "value": "open"}
#   user.teaming_partner: {"doc_id": "doc_9_d5cc8dfc", "tag": "teaming_partner", "value": "especially"}
#   user.handling_descriptor: {"doc_id": "doc_9_d5cc8dfc", "tag": "handling_descriptor", "value": "world"}
#   user.distribution_statement: {"doc_id": "doc_9_d5cc8dfc", "tag": "distribution_statement", "value": "reflect"}
#   user.sci_control: {"doc_id": "doc_9_d5cc8dfc", "tag": "sci_control", "value": "standard"}
#   user.caveats: {"doc_id": "doc_9_d5cc8dfc", "tag": "caveats", "value": "thought"}
#   user.ps_percent_complete: {"doc_id": "doc_9_d5cc8dfc", "tag": "ps_percent_complete", "value": "crime"}
#   user.point_of_contact: {"doc_id": "doc_9_d5cc8dfc", "tag": "point_of_contact", "value": "difficult"}
#   user.report_version: {"doc_id": "doc_9_d5cc8dfc", "tag": "report_version", "value": "type"}
#   user.system_of_record: {"doc_id": "doc_9_d5cc8dfc", "tag": "system_of_record", "value": "human"}
#   user.citation: {"doc_id": "doc_9_d5cc8dfc", "tag": "citation", "value": "bill"}
#   user.related_doc: {"doc_id": "doc_9_d5cc8dfc", "tag": "related_doc", "value": "can"}
#   user.platform: {"doc_id": "doc_9_d5cc8dfc", "tag": "platform", "value": "evidence"}
#   user.environment: {"doc_id": "doc_9_d5cc8dfc", "tag": "environment", "value": "product"}
#   user.operation_name: {"doc_id": "doc_9_d5cc8dfc", "tag": "operation_name", "value": "long"}
#   user.mission_area: {"doc_id": "doc_9_d5cc8dfc", "tag": "mission_area", "value": "spring"}
#   user.geo_scope: {"doc_id": "doc_9_d5cc8dfc", "tag": "geo_scope", "value": "item"}
#   user.cyber_domain: {"doc_id": "doc_9_d5cc8dfc", "tag": "cyber_domain", "value": "box"}
#   user.policy_impact: {"doc_id": "doc_9_d5cc8dfc", "tag": "policy_impact", "value": "help"}
#   user.audit_trail: {"doc_id": "doc_9_d5cc8dfc", "tag": "audit_trail", "value": "likely"}
#
# file_name: populate_xattr.sh
# block_size: 4096
# permission: 764
# links: 1
# owner: jrsmith
# group: jrsmith
# size: 2447
# mod_time: Aug 26 15:10
# plus xattr metadata: None
